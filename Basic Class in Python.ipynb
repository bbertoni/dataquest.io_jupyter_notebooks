# %% [markdown]
# # BabyPandas Class
# ### We will be creating a baby version of the pandas class called BabyPandas.  This class will allow us to use Spotify data to help us to answer the question:
# - Which song had the highest number of plays in one day?

# %% [markdown]
# BabyPandas -> **Class**
# Load -> **Method**
# Data -> **Attribute**
# Columns -> **Attribute**
#
# Preview
# View the first five rows -> **Method**
# View number of rows/cols in our data -> **Method**
# View the data types for each column -> **Method**
#
# Manipulate
# Add new columns -> **Method**
# Apply values to columns -> **Method**
# Subset our data -> **Method**
# Change the data type -> **Method**
#
# Calculations
# Minimum -> **Method**
# Maximum -> **Method**
# Mean -> **Method**
# Standard deviation -> **Method**

# %%
import statistics

class BabyPandas():
    
    def __init__(self,filename):
        self.filename = filename
        
    def read_data(self):
        file = open(self.filename,"r")
        filestring = file.read()
        stringlist = filestring.split("\n")
        data = []
        for row in stringlist:
            data.append(row.split(","))
        ncol = len(data[0])
        final_data = []
        for row in data:
            if len(row)==ncol:
                final_data.append(row)
        self.columns = final_data[0]
        self.data = final_data
        
    def head(self):
        return self.data[0:5]
    
    def info(self):
        types = []
        for col in self.data[1]:
            types.append(type(col))
        return types
    
    def shape(self):
        nrow = 0
        for row in self.data[1:]:
            nrow += 1
        ncol = len(self.data[1])
        return (nrow, ncol)

    def new_column(self,colname):
        for pos,d in enumerate(self.data):
            if pos==0:
                d.append(colname)
            else:
                d.append("N/A")
    
    def apply(self,index,values,row):
        if row==True:
            self.data[index]=values
        else:
            i=0
            for row in self.data:
                row[index] = values[i]
                i += 1
    
    def subset(self,col_index,rowval):
        # keep rows where column has rowval
        new_data = []
        for row in self.data:
            if row[col_index]==rowval:
                new_data.append(row)
        self.data = new_data
    
    def change_type(self,index,new_type):
        for row in self.data:
            row[index] = new_type(row[index])
            
    def summary_stats(self,col_index):
        col = []
        for row in self.data:
            col.append(row[col_index])
        mean = statistics.mean(col)
        median = statistics.median(col)
        try:
            mode = statistics.mode(col)
        except:
            mode = "undefined, likely all values different"
        stdev = statistics.stdev(col)
        string = "The {} is {}.\n"
        print(string.format("mean",str(mean)) + string.format("median",str(median)) + string.format("mode",str(mode)) + string.format("stdev",str(stdev)))
        
    def maximum(self,col_index):
        col = []
        for row in self.data:
            col.append(row[col_index])
        return max(col)
    
    def minimum(self,col_index):
        col = []
        for row in self.data:
            col.append(row[col_index])
        return min(col)

# %% [markdown]
# ## Test out the functionality

# %%
music = BabyPandas("music_data.csv")

# %%
music.filename
# Out:
# 'music_data.csv'

# %%
music.read_data()

# %%
music.columns
# looks like the columns are weird...oh well, 
# work around this for now
# Out:
# ['', 'Track Name', 'Artist', 'Streams', 'Date', 'Region']

# %%
music.data
# Out:
# [['', 'Track Name', 'Artist', 'Streams', 'Date', 'Region'],
#  ['0', 'Reggaetón Lento (Bailemos)', 'CNCO', '19272', '2017-01-01', 'ec'],
#  ['1', 'Chantaje', 'Shakira', '19270', '2017-01-01', 'ec'],
#  ['2',
#   'Otra Vez (feat. J Balvin)',
#   'Zion & Lennox',
#   '15761',
#   '2017-01-01',
#   'ec'],
#  ['3', "Vente Pa' Ca", 'Ricky Martin', '14954', '2017-01-01', 'ec'],
#  ['4', 'Safari', 'J Balvin', '14269', '2017-01-01', 'ec'],
#  ['5', 'La Bicicleta', 'Carlos Vives', '12843', '2017-01-01', 'ec'],
#  ['6', 'Ay Mi Dios', 'IAmChino', '10986', '2017-01-01', 'ec'],
#  ['7', 'Andas En Mi Cabeza', 'Chino & Nacho', '10653', '2017-01-01', 'ec'],
#  ['8', 'Traicionera', 'Sebastian Yatra', '9807', '2017-01-01', 'ec'],
#  ['9', 'Shaky Shaky', 'Daddy Yankee', '9612', '2017-01-01', 'ec'],
#  ['10', 'Vacaciones', 'Wisin', '9611', '2017-01-01', 'ec'],
#  ['11', 'Dile Que Tu Me Quieres', 'Ozuna', '8982', '2017-01-01', 'ec'],
#  ['12', 'Let Me Love You', 'DJ Snake', '8834', '2017-01-01', 'ec'],
#  ['13', 'DUELE EL CORAZON', 'Enrique Iglesias', '8309', '2017-01-01', 'ec'],
#  ['14', 'Chillax', 'Farruko', '7822', '2017-01-01', 'ec'],
#  ['15', 'Borro Cassette', 'Maluma', '7586', '2017-01-01', 'ec'],
#  ['16', 'One Dance', 'Drake', '7472', '2017-01-01', 'ec'],
#  ['17', 'Closer', 'The Chainsmokers', '7416', '2017-01-01', 'ec'],
#  ['18', 'Starboy', 'The Weeknd', '7006', '2017-01-01', 'ec'],
#  ['19', 'Desde Esa Noche', 'Thalía', '6779', '2017-01-01', 'ec'],
#  ['20', "Don't Wanna Know", 'Maroon 5', '6582', '2017-01-01', 'ec'],
#  ['21', 'La Gozadera', 'Gente De Zona', '6521', '2017-01-01', 'ec'],
#  ['22', '24K Magic', 'Bruno Mars', '6261', '2017-01-01', 'ec'],
#  ['23',
#   'Me Llamas (feat. Maluma) - Remix',
#   'Piso 21',
#   '6237',
#   '2017-01-01',
#   'ec'],
#  ['24', 'Cuatro Babys', 'Maluma', '6028', '2017-01-01', 'ec'],
#  ['25', 'My Way', 'Calvin Harris', '5723', '2017-01-01', 'ec'],
#  ['26', 'Gyal You A Party Animal', 'Charly Black', '5601', '2017-01-01', 'ec'],
#  ['27', 'Baila Conmigo', 'Juan Magán', '5586', '2017-01-01', 'ec'],
#  ['28',
#   'Gyal You A Party Animal - Remix',
#   'Charly Black',
#   '5541',
#   '2017-01-01',
#   'ec'],
#  ['29',
#   "We Don't Talk Anymore (feat. Selena Gomez)",
#   'Charlie Puth',
#   '5362',
#   '2017-01-01',
#   'ec'],
#  ['30', 'Por Fin Te Encontré', 'Cali Y El Dandee', '5259', '2017-01-01', 'ec'],
#  ['31',
#   '"CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s ""TROLLS"")"',
#   'Justin Timberlake',
#   '5198',
#   '2017-01-01',
#   'ec'],
#  ['32', 'Bailame Despacio', 'Xantos', '5160', '2017-01-01', 'ec'],
#  ['33',
#   'I Took A Pill In Ibiza - Seeb Remix',
#   'Mike Posner',
#   '5025',
#   '2017-01-01',
#   'ec'],
#  ['34', 'Hasta el Amanecer', 'Nicky Jam', '5001', '2017-01-01', 'ec'],
#  ['35',
#   'Cold Water (feat. Justin Bieber & MØ)',
#   'Major Lazer',
#   '4933',
#   '2017-01-01',
#   'ec'],
#  ['36', 'Bobo', 'J Balvin', '4781', '2017-01-01', 'ec'],
#  ['37',
#   'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#   'Reik',
#   '4644',
#   '2017-01-01',
#   'ec'],
#  ['38', 'In the Name of Love', 'Martin Garrix', '4609', '2017-01-01', 'ec'],
#  ['39', "Don't Let Me Down", 'The Chainsmokers', '4379', '2017-01-01', 'ec'],
#  ['40', 'Cheap Thrills', 'Sia', '4300', '2017-01-01', 'ec'],
#  ['41', 'Fuego', 'Juanes', '4286', '2017-01-01', 'ec'],
#  ['42', 'Tan Fácil', 'CNCO', '4205', '2017-01-01', 'ec'],
#  ['43',
#   'Rockabye (feat. Sean Paul & Anne-Marie)',
#   'Clean Bandit',
#   '4103',
#   '2017-01-01',
#   'ec'],
#  ['44', 'Treat You Better', 'Shawn Mendes', '3941', '2017-01-01', 'ec'],
#  ['45', 'Enamorándonos', 'Cabas', '3734', '2017-01-01', 'ec'],
#  ['46', 'Te Vas', 'Ozuna', '3721', '2017-01-01', 'ec'],
#  ['47',
#   'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#   'Ozuna',
#   '3467',
#   '2017-01-01',
#   'ec'],
#  ['48', 'Te Quiero Pa´Mi', 'Don Omar', '3467', '2017-01-01', 'ec'],
#  ['49', 'Heathens', 'Twenty One Pilots', '3376', '2017-01-01', 'ec'],
#  ['50',
#   'Hasta Que Se Seque el Malecón - Remix',
#   'Jacob Forever',
#   '3368',
#   '2017-01-01',
#   'ec'],
#  ['52', 'Deja Que Te Bese', 'Alejandro Sanz', '3321', '2017-01-01', 'ec'],
#  ['53', 'Side To Side', 'Ariana Grande', '3275', '2017-01-01', 'ec'],
#  ['54', 'Manicomio', 'Cosculluela', '3180', '2017-01-01', 'ec'],
#  ['55', 'Ruleta Rusa', 'Kevin Roldan', '3085', '2017-01-01', 'ec'],
#  ['56', 'I Feel It Coming', 'The Weeknd', '3022', '2017-01-01', 'ec'],
#  ['57', 'Ginza', 'J Balvin', '3005', '2017-01-01', 'ec'],
#  ['58', 'Work', 'Rihanna', '2967', '2017-01-01', 'ec'],
#  ['59', 'Cake By The Ocean', 'DNCE', '2955', '2017-01-01', 'ec'],
#  ['60', 'Picky', 'Joey Montana', '2922', '2017-01-01', 'ec'],
#  ['61',
#   'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#   'Major Lazer',
#   '2863',
#   '2017-01-01',
#   'ec'],
#  ['62',
#   'This Is What You Came For',
#   'Calvin Harris',
#   '2860',
#   '2017-01-01',
#   'ec'],
#  ['63',
#   'Bailando - Spanish Version',
#   'Enrique Iglesias',
#   '2817',
#   '2017-01-01',
#   'ec'],
#  ['64',
#   'Corazon De Seda (feat. Ozuna)',
#   'Klasico',
#   '2815',
#   '2017-01-01',
#   'ec'],
#  ['65', 'El Perdón', 'Nicky Jam', '2801', '2017-01-01', 'ec'],
#  ['66', 'El Perdedor', 'Maluma', '2684', '2017-01-01', 'ec'],
#  ['67', 'Traicionera - Remix', 'Sebastian Yatra', '2663', '2017-01-01', 'ec'],
#  ['68', 'Encantadora', 'Yandel', '2611', '2017-01-01', 'ec'],
#  ['69', 'Ride', 'Twenty One Pilots', '2604', '2017-01-01', 'ec'],
#  ['70', 'Love Yourself', 'Justin Bieber', '2581', '2017-01-01', 'ec'],
#  ['71', 'Encantadora - Remix', 'Yandel', '2554', '2017-01-01', 'ec'],
#  ['72', 'Materialista', 'Silvestre Dangond', '2493', '2017-01-01', 'ec'],
#  ['73',
#   'Me Voy Enamorando - Remix',
#   'Chino & Nacho',
#   '2482',
#   '2017-01-01',
#   'ec'],
#  ['74', 'Vivir Mi Vida', 'Marc Anthony', '2446', '2017-01-01', 'ec'],
#  ['75', 'Faded', 'Alan Walker', '2442', '2017-01-01', 'ec'],
#  ['76', 'Work from Home', 'Fifth Harmony', '2440', '2017-01-01', 'ec'],
#  ['77', 'El Perdedor - The Remix', 'Maluma', '2429', '2017-01-01', 'ec'],
#  ['78', 'Stressed Out', 'Twenty One Pilots', '2370', '2017-01-01', 'ec'],
#  ['79', 'De Pies a Cabeza', 'Maná', '2351', '2017-01-01', 'ec'],
#  ['80', 'Quisiera', 'CNCO', '2347', '2017-01-01', 'ec'],
#  ['81',
#   'Te Busco (feat. Nicky Jam)',
#   'Cosculluela',
#   '2330',
#   '2017-01-01',
#   'ec'],
#  ['82', 'Perfect Strangers', 'Jonas Blue', '2329', '2017-01-01', 'ec'],
#  ['83',
#   'Hymn For The Weekend - Seeb Remix',
#   'Coldplay',
#   '2327',
#   '2017-01-01',
#   'ec'],
#  ['84', 'El Chisme', 'Reykon', '2312', '2017-01-01', 'ec'],
#  ['85', 'Noche Loca', 'Marama', '2304', '2017-01-01', 'ec'],
#  ['86', 'La Bicicleta - Remix', 'Carlos Vives', '2292', '2017-01-01', 'ec'],
#  ['87', 'La Mordidita', 'Ricky Martin', '2290', '2017-01-01', 'ec'],
#  ['89', 'Sin Contrato', 'Maluma', '2212', '2017-01-01', 'ec'],
#  ['90', 'Locuras contigo', 'Rombai', '2212', '2017-01-01', 'ec'],
#  ['91',
#   'Mi Tesoro (feat. Nicky Jam)',
#   'Zion & Lennox',
#   '2202',
#   '2017-01-01',
#   'ec'],
#  ['92', 'Trumpets', 'Sak Noel & Salvi', '2183', '2017-01-01', 'ec'],
#  ['93', 'Me Rehúso', 'Danny Ocean', '2175', '2017-01-01', 'ec'],
#  ['95', 'Nota de Amor', 'Wisin', '2150', '2017-01-01', 'ec'],
#  ['96', 'Me Ama Me Odia', 'Ozuna', '2140', '2017-01-01', 'ec'],
#  ['97',
#   'Valió la Pena - Salsa Version',
#   'Marc Anthony',
#   '2135',
#   '2017-01-01',
#   'ec'],
#  ['98', 'Me llamas', 'Piso 21', '2109', '2017-01-01', 'ec'],
#  ['99', 'Time of Our Lives', 'Pitbull', '2101', '2017-01-01', 'ec'],
#  ['100', 'Reggaetón Lento (Bailemos)', 'CNCO', '16672', '2017-01-02', 'ec'],
#  ['101', 'Chantaje', 'Shakira', '15594', '2017-01-02', 'ec'],
#  ['102',
#   'Otra Vez (feat. J Balvin)',
#   'Zion & Lennox',
#   '13507',
#   '2017-01-02',
#   'ec'],
#  ['103', 'Safari', 'J Balvin', '11958', '2017-01-02', 'ec'],
#  ['104', "Vente Pa' Ca", 'Ricky Martin', '11590', '2017-01-02', 'ec'],
#  ['105', 'Let Me Love You', 'DJ Snake', '9096', '2017-01-02', 'ec'],
#  ['106', 'Ay Mi Dios', 'IAmChino', '9023', '2017-01-02', 'ec'],
#  ['107', 'Traicionera', 'Sebastian Yatra', '8511', '2017-01-02', 'ec'],
#  ['108', 'La Bicicleta', 'Carlos Vives', '8288', '2017-01-02', 'ec'],
#  ['109', 'Vacaciones', 'Wisin', '8205', '2017-01-02', 'ec'],
#  ['110', 'Closer', 'The Chainsmokers', '8075', '2017-01-02', 'ec'],
#  ['111', 'Dile Que Tu Me Quieres', 'Ozuna', '8048', '2017-01-02', 'ec'],
#  ['112', 'Andas En Mi Cabeza', 'Chino & Nacho', '7732', '2017-01-02', 'ec'],
#  ['113', 'One Dance', 'Drake', '7437', '2017-01-02', 'ec'],
#  ['114', 'Starboy', 'The Weeknd', '7330', '2017-01-02', 'ec'],
#  ['115', 'Shaky Shaky', 'Daddy Yankee', '6974', '2017-01-02', 'ec'],
#  ['116', 'Chillax', 'Farruko', '6905', '2017-01-02', 'ec'],
#  ['117', "Don't Wanna Know", 'Maroon 5', '6883', '2017-01-02', 'ec'],
#  ['118', 'Cuatro Babys', 'Maluma', '6370', '2017-01-02', 'ec'],
#  ['119', '24K Magic', 'Bruno Mars', '6287', '2017-01-02', 'ec'],
#  ['120', 'DUELE EL CORAZON', 'Enrique Iglesias', '6205', '2017-01-02', 'ec'],
#  ['121', 'My Way', 'Calvin Harris', '6032', '2017-01-02', 'ec'],
#  ['122',
#   'Me Llamas (feat. Maluma) - Remix',
#   'Piso 21',
#   '5875',
#   '2017-01-02',
#   'ec'],
#  ['123', 'Borro Cassette', 'Maluma', '5822', '2017-01-02', 'ec'],
#  ['124',
#   "We Don't Talk Anymore (feat. Selena Gomez)",
#   'Charlie Puth',
#   '5643',
#   '2017-01-02',
#   'ec'],
#  ['125',
#   'I Took A Pill In Ibiza - Seeb Remix',
#   'Mike Posner',
#   '5500',
#   '2017-01-02',
#   'ec'],
#  ['126',
#   'Cold Water (feat. Justin Bieber & MØ)',
#   'Major Lazer',
#   '5363',
#   '2017-01-02',
#   'ec'],
#  ['127', 'In the Name of Love', 'Martin Garrix', '4915', '2017-01-02', 'ec'],
#  ['128', 'Desde Esa Noche', 'Thalía', '4912', '2017-01-02', 'ec'],
#  ['129',
#   'Gyal You A Party Animal - Remix',
#   'Charly Black',
#   '4894',
#   '2017-01-02',
#   'ec'],
#  ['130', 'Baila Conmigo', 'Juan Magán', '4888', '2017-01-02', 'ec'],
#  ['131', "Don't Let Me Down", 'The Chainsmokers', '4879', '2017-01-02', 'ec'],
#  ['132',
#   '"CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s ""TROLLS"")"',
#   'Justin Timberlake',
#   '4762',
#   '2017-01-02',
#   'ec'],
#  ['133',
#   'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#   'Reik',
#   '4708',
#   '2017-01-02',
#   'ec'],
#  ['134', 'Bailame Despacio', 'Xantos', '4692', '2017-01-02', 'ec'],
#  ['135', 'Cheap Thrills', 'Sia', '4569', '2017-01-02', 'ec'],
#  ['136', 'Bobo', 'J Balvin', '4520', '2017-01-02', 'ec'],
#  ['137', 'Treat You Better', 'Shawn Mendes', '4498', '2017-01-02', 'ec'],
#  ['138',
#   'Gyal You A Party Animal',
#   'Charly Black',
#   '4417',
#   '2017-01-02',
#   'ec'],
#  ['139', 'La Gozadera', 'Gente De Zona', '4309', '2017-01-02', 'ec'],
#  ['140',
#   'Rockabye (feat. Sean Paul & Anne-Marie)',
#   'Clean Bandit',
#   '4284',
#   '2017-01-02',
#   'ec'],
#  ['141', 'Hasta el Amanecer', 'Nicky Jam', '4149', '2017-01-02', 'ec'],
#  ['142', 'Fuego', 'Juanes', '3976', '2017-01-02', 'ec'],
#  ['143', 'Tan Fácil', 'CNCO', '3975', '2017-01-02', 'ec'],
#  ['144', 'Heathens', 'Twenty One Pilots', '3970', '2017-01-02', 'ec'],
#  ['145', 'Te Vas', 'Ozuna', '3910', '2017-01-02', 'ec'],
#  ['146',
#   'Por Fin Te Encontré',
#   'Cali Y El Dandee',
#   '3751',
#   '2017-01-02',
#   'ec'],
#  ['147', 'Te Quiero Pa´Mi', 'Don Omar', '3618', '2017-01-02', 'ec'],
#  ['149', 'I Feel It Coming', 'The Weeknd', '3484', '2017-01-02', 'ec'],
#  ['150',
#   'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#   'Ozuna',
#   '3450',
#   '2017-01-02',
#   'ec'],
#  ['151', 'Side To Side', 'Ariana Grande', '3361', '2017-01-02', 'ec'],
#  ['152', 'Enamorándonos', 'Cabas', '3321', '2017-01-02', 'ec'],
#  ['153',
#   'This Is What You Came For',
#   'Calvin Harris',
#   '3194',
#   '2017-01-02',
#   'ec'],
#  ['154', 'Ride', 'Twenty One Pilots', '3126', '2017-01-02', 'ec'],
#  ['155', 'Manicomio', 'Cosculluela', '3118', '2017-01-02', 'ec'],
#  ['156', 'Deja Que Te Bese', 'Alejandro Sanz', '3081', '2017-01-02', 'ec'],
#  ['157', 'Faded', 'Alan Walker', '3060', '2017-01-02', 'ec'],
#  ['158', 'Ruleta Rusa', 'Kevin Roldan', '3052', '2017-01-02', 'ec'],
#  ['159', 'Work', 'Rihanna', '3001', '2017-01-02', 'ec'],
#  ['160', 'Cake By The Ocean', 'DNCE', '2996', '2017-01-02', 'ec'],
#  ['161', 'Photograph', 'Ed Sheeran', '2919', '2017-01-02', 'ec'],
#  ['162',
#   'Hasta Que Se Seque el Malecón - Remix',
#   'Jacob Forever',
#   '2912',
#   '2017-01-02',
#   'ec'],
#  ['163', 'Work from Home', 'Fifth Harmony', '2805', '2017-01-02', 'ec'],
#  ['164', 'Stressed Out', 'Twenty One Pilots', '2797', '2017-01-02', 'ec'],
#  ['165',
#   'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#   'Major Lazer',
#   '2673',
#   '2017-01-02',
#   'ec'],
#  ['166', 'Love Yourself', 'Justin Bieber', '2652', '2017-01-02', 'ec'],
#  ['167',
#   'Corazon De Seda (feat. Ozuna)',
#   'Klasico',
#   '2602',
#   '2017-01-02',
#   'ec'],
#  ['168',
#   'Hymn For The Weekend - Seeb Remix',
#   'Coldplay',
#   '2519',
#   '2017-01-02',
#   'ec'],
#  ['170', 'Me Rehúso', 'Danny Ocean', '2460', '2017-01-02', 'ec'],
#  ['171', 'Perfect Strangers', 'Jonas Blue', '2436', '2017-01-02', 'ec'],
#  ['173', 'Thinking Out Loud', 'Ed Sheeran', '2430', '2017-01-02', 'ec'],
#  ['174', 'Quisiera', 'CNCO', '2429', '2017-01-02', 'ec'],
#  ['175', 'Encantadora - Remix', 'Yandel', '2355', '2017-01-02', 'ec'],
#  ['176', 'Bajo el agua', 'Manuel Medrano', '2344', '2017-01-02', 'ec'],
#  ['177', 'El Chisme', 'Reykon', '2335', '2017-01-02', 'ec'],
#  ['178', 'Traicionera - Remix', 'Sebastian Yatra', '2317', '2017-01-02', 'ec'],
#  ['179', 'Me Ama Me Odia', 'Ozuna', '2293', '2017-01-02', 'ec'],
#  ['180', 'Just Hold On', 'Steve Aoki', '2269', '2017-01-02', 'ec'],
#  ['181', 'Que Raro', 'Feid', '2260', '2017-01-02', 'ec'],
#  ['182',
#   'Te Busco (feat. Nicky Jam)',
#   'Cosculluela',
#   '2255',
#   '2017-01-02',
#   'ec'],
#  ['183', 'Encantadora', 'Yandel', '2238', '2017-01-02', 'ec'],
#  ['184',
#   '"I Don’t Wanna Live Forever (Fifty Shades Darker) - From ""Fifty Shades Darker (Original Motion Picture Soundtrack)"""',
#   'ZAYN',
#   '2220',
#   '2017-01-02',
#   'ec'],
#  ['185', 'Ya Me Enteré', 'Reik', '2183', '2017-01-02', 'ec'],
#  ['186',
#   'Mi Tesoro (feat. Nicky Jam)',
#   'Zion & Lennox',
#   '2173',
#   '2017-01-02',
#   'ec'],
#  ['187', 'Una y otra vez', 'Manuel Medrano', '2138', '2017-01-02', 'ec'],
#  ['188', 'Ginza', 'J Balvin', '2135', '2017-01-02', 'ec'],
#  ['189', 'Black Beatles', 'Rae Sremmurd', '2123', '2017-01-02', 'ec'],
#  ['190', 'Middle', 'DJ Snake', '2119', '2017-01-02', 'ec'],
#  ['191', 'The Greatest', 'Sia', '2112', '2017-01-02', 'ec'],
#  ['192', 'El Perdedor - The Remix', 'Maluma', '2084', '2017-01-02', 'ec'],
#  ['193', 'De Pies a Cabeza', 'Maná', '2067', '2017-01-02', 'ec'],
#  ['194', 'Me llamas', 'Piso 21', '2051', '2017-01-02', 'ec'],
#  ['195', "Say You Won't Let Go", 'James Arthur', '2051', '2017-01-02', 'ec'],
#  ['196', 'All We Know', 'The Chainsmokers', '2047', '2017-01-02', 'ec'],
#  ['197', 'Mercy', 'Shawn Mendes', '2038', '2017-01-02', 'ec'],
#  ['198', 'El Perdedor', 'Maluma', '2035', '2017-01-02', 'ec'],
#  ['199', 'Starving', 'Hailee Steinfeld', '2019', '2017-01-02', 'ec'],
#  ['200', 'Reggaetón Lento (Bailemos)', 'CNCO', '17258', '2017-01-03', 'ec'],
#  ['201', 'Chantaje', 'Shakira', '16614', '2017-01-03', 'ec'],
#  ['202',
#   'Otra Vez (feat. J Balvin)',
#   'Zion & Lennox',
#   '14148',
#   '2017-01-03',
#   'ec'],
#  ['203', 'Safari', 'J Balvin', '12336', '2017-01-03', 'ec'],
#  ['204', "Vente Pa' Ca", 'Ricky Martin', '12280', '2017-01-03', 'ec'],
#  ['205', 'Let Me Love You', 'DJ Snake', '10652', '2017-01-03', 'ec'],
#  ['206', 'Ay Mi Dios', 'IAmChino', '9519', '2017-01-03', 'ec'],
#  ['207', 'Closer', 'The Chainsmokers', '9244', '2017-01-03', 'ec'],
#  ['208', 'Vacaciones', 'Wisin', '9032', '2017-01-03', 'ec'],
#  ['209', 'Traicionera', 'Sebastian Yatra', '8993', '2017-01-03', 'ec'],
#  ['210', 'Starboy', 'The Weeknd', '8676', '2017-01-03', 'ec'],
#  ['211', 'Dile Que Tu Me Quieres', 'Ozuna', '8425', '2017-01-03', 'ec'],
#  ['212', 'One Dance', 'Drake', '8357', '2017-01-03', 'ec'],
#  ['213', "Don't Wanna Know", 'Maroon 5', '8281', '2017-01-03', 'ec'],
#  ['214', 'La Bicicleta', 'Carlos Vives', '8039', '2017-01-03', 'ec'],
#  ['215', 'Andas En Mi Cabeza', 'Chino & Nacho', '7821', '2017-01-03', 'ec'],
#  ['216', 'Chillax', 'Farruko', '7772', '2017-01-03', 'ec'],
#  ['217', '24K Magic', 'Bruno Mars', '7395', '2017-01-03', 'ec'],
#  ['218', 'My Way', 'Calvin Harris', '7229', '2017-01-03', 'ec'],
#  ['219', 'Cuatro Babys', 'Maluma', '6990', '2017-01-03', 'ec'],
#  ['220', 'Shaky Shaky', 'Daddy Yankee', '6854', '2017-01-03', 'ec'],
#  ['221',
#   "We Don't Talk Anymore (feat. Selena Gomez)",
#   'Charlie Puth',
#   '6686',
#   '2017-01-03',
#   'ec'],
#  ['222',
#   'Cold Water (feat. Justin Bieber & MØ)',
#   'Major Lazer',
#   '6646',
#   '2017-01-03',
#   'ec'],
#  ['223',
#   'Me Llamas (feat. Maluma) - Remix',
#   'Piso 21',
#   '6118',
#   '2017-01-03',
#   'ec'],
#  ['224', 'DUELE EL CORAZON', 'Enrique Iglesias', '6106', '2017-01-03', 'ec'],
#  ['225',
#   'I Took A Pill In Ibiza - Seeb Remix',
#   'Mike Posner',
#   '6050',
#   '2017-01-03',
#   'ec'],
#  ['226', 'Borro Cassette', 'Maluma', '5927', '2017-01-03', 'ec'],
#  ['227', 'In the Name of Love', 'Martin Garrix', '5791', '2017-01-03', 'ec'],
#  ['228', "Don't Let Me Down", 'The Chainsmokers', '5602', '2017-01-03', 'ec'],
#  ['229',
#   'Rockabye (feat. Sean Paul & Anne-Marie)',
#   'Clean Bandit',
#   '5535',
#   '2017-01-03',
#   'ec'],
#  ['230', 'Treat You Better', 'Shawn Mendes', '5436', '2017-01-03', 'ec'],
#  ['231', 'Bailame Despacio', 'Xantos', '5430', '2017-01-03', 'ec'],
#  ['232',
#   '"CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s ""TROLLS"")"',
#   'Justin Timberlake',
#   '5361',
#   '2017-01-03',
#   'ec'],
#  ['233', 'Cheap Thrills', 'Sia', '5108', '2017-01-03', 'ec'],
#  ['234',
#   'Gyal You A Party Animal - Remix',
#   'Charly Black',
#   '5102',
#   '2017-01-03',
#   'ec'],
#  ['235',
#   'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#   'Reik',
#   '5014',
#   '2017-01-03',
#   'ec'],
#  ['236', 'Baila Conmigo', 'Juan Magán', '4984', '2017-01-03', 'ec'],
#  ['237', 'Desde Esa Noche', 'Thalía', '4974', '2017-01-03', 'ec'],
#  ['238', 'I Feel It Coming', 'The Weeknd', '4891', '2017-01-03', 'ec'],
#  ['239', 'Bobo', 'J Balvin', '4629', '2017-01-03', 'ec'],
#  ['240', 'Heathens', 'Twenty One Pilots', '4443', '2017-01-03', 'ec'],
#  ['241',
#   'Gyal You A Party Animal',
#   'Charly Black',
#   '4442',
#   '2017-01-03',
#   'ec'],
#  ['242', 'Fuego', 'Juanes', '4345', '2017-01-03', 'ec'],
#  ['243', 'Te Quiero Pa´Mi', 'Don Omar', '4244', '2017-01-03', 'ec'],
#  ['244', 'La Gozadera', 'Gente De Zona', '4233', '2017-01-03', 'ec'],
#  ['245', 'Tan Fácil', 'CNCO', '4173', '2017-01-03', 'ec'],
#  ['246', 'Hasta el Amanecer', 'Nicky Jam', '4085', '2017-01-03', 'ec'],
#  ['248', 'Te Vas', 'Ozuna', '3935', '2017-01-03', 'ec'],
#  ['249', 'Side To Side', 'Ariana Grande', '3904', '2017-01-03', 'ec'],
#  ['250',
#   'Por Fin Te Encontré',
#   'Cali Y El Dandee',
#   '3626',
#   '2017-01-03',
#   'ec'],
#  ['251', 'Photograph', 'Ed Sheeran', '3582', '2017-01-03', 'ec'],
#  ['252',
#   'This Is What You Came For',
#   'Calvin Harris',
#   '3554',
#   '2017-01-03',
#   'ec'],
#  ['253', 'Ride', 'Twenty One Pilots', '3467', '2017-01-03', 'ec'],
#  ['254', 'Cake By The Ocean', 'DNCE', '3448', '2017-01-03', 'ec'],
#  ['255',
#   'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#   'Ozuna',
#   '3336',
#   '2017-01-03',
#   'ec'],
#  ['256', 'Enamorándonos', 'Cabas', '3327', '2017-01-03', 'ec'],
#  ['257', 'Work from Home', 'Fifth Harmony', '3300', '2017-01-03', 'ec'],
#  ['258', 'Deja Que Te Bese', 'Alejandro Sanz', '3254', '2017-01-03', 'ec'],
#  ['259',
#   '"I Don’t Wanna Live Forever (Fifty Shades Darker) - From ""Fifty Shades Darker (Original Motion Picture Soundtrack)"""',
#   'ZAYN',
#   '3191',
#   '2017-01-03',
#   'ec'],
#  ['260', 'Ruleta Rusa', 'Kevin Roldan', '3185', '2017-01-03', 'ec'],
#  ['261', 'Faded', 'Alan Walker', '3176', '2017-01-03', 'ec'],
#  ['262', 'Manicomio', 'Cosculluela', '3160', '2017-01-03', 'ec'],
#  ['263', 'Work', 'Rihanna', '3105', '2017-01-03', 'ec'],
#  ['264', 'Stressed Out', 'Twenty One Pilots', '3095', '2017-01-03', 'ec'],
#  ['265', 'Thinking Out Loud', 'Ed Sheeran', '3076', '2017-01-03', 'ec'],
#  ['266', 'Una y otra vez', 'Manuel Medrano', '3017', '2017-01-03', 'ec'],
#  ['267', 'Me Rehúso', 'Danny Ocean', '3008', '2017-01-03', 'ec'],
#  ['268', 'Love Yourself', 'Justin Bieber', '2997', '2017-01-03', 'ec'],
#  ['269',
#   'Hymn For The Weekend - Seeb Remix',
#   'Coldplay',
#   '2946',
#   '2017-01-03',
#   'ec'],
#  ['270',
#   'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#   'Major Lazer',
#   '2830',
#   '2017-01-03',
#   'ec'],
#  ['272', 'Bajo el agua', 'Manuel Medrano', '2761', '2017-01-03', 'ec'],
#  ['273',
#   'Hasta Que Se Seque el Malecón - Remix',
#   'Jacob Forever',
#   '2738',
#   '2017-01-03',
#   'ec'],
#  ['274', 'Perfect Strangers', 'Jonas Blue', '2732', '2017-01-03', 'ec'],
#  ['275', "Say You Won't Let Go", 'James Arthur', '2683', '2017-01-03', 'ec'],
#  ['276', 'Quisiera', 'CNCO', '2651', '2017-01-03', 'ec'],
#  ['277', 'Just Hold On', 'Steve Aoki', '2641', '2017-01-03', 'ec'],
#  ['278', 'Ya Me Enteré', 'Reik', '2594', '2017-01-03', 'ec'],
#  ['279', 'Starving', 'Hailee Steinfeld', '2588', '2017-01-03', 'ec'],
#  ['281',
#   'Corazon De Seda (feat. Ozuna)',
#   'Klasico',
#   '2573',
#   '2017-01-03',
#   'ec'],
#  ['282', 'Que Raro', 'Feid', '2541', '2017-01-03', 'ec'],
#  ['283', 'El Chisme', 'Reykon', '2538', '2017-01-03', 'ec'],
#  ['284', 'All We Know', 'The Chainsmokers', '2523', '2017-01-03', 'ec'],
#  ['285', 'Black Beatles', 'Rae Sremmurd', '2502', '2017-01-03', 'ec'],
#  ['286', 'Encantadora - Remix', 'Yandel', '2491', '2017-01-03', 'ec'],
#  ['287', 'Dueles', 'Jesse & Joy', '2464', '2017-01-03', 'ec'],
#  ['288', 'Encantadora', 'Yandel', '2455', '2017-01-03', 'ec'],
#  ['289', 'Mercy', 'Shawn Mendes', '2425', '2017-01-03', 'ec'],
#  ['290', 'The Greatest', 'Sia', '2411', '2017-01-03', 'ec'],
#  ['291', 'Middle', 'DJ Snake', '2361', '2017-01-03', 'ec'],
#  ['292', 'Fake Love', 'Drake', '2357', '2017-01-03', 'ec'],
#  ['293',
#   'Mi Tesoro (feat. Nicky Jam)',
#   'Zion & Lennox',
#   '2355',
#   '2017-01-03',
#   'ec'],
#  ['294', 'Traicionera - Remix', 'Sebastian Yatra', '2296', '2017-01-03', 'ec'],
#  ['295', 'Me Ama Me Odia', 'Ozuna', '2234', '2017-01-03', 'ec'],
#  ['296', 'Me llamas', 'Piso 21', '2227', '2017-01-03', 'ec'],
#  ['297',
#   'Te Busco (feat. Nicky Jam)',
#   'Cosculluela',
#   '2165',
#   '2017-01-03',
#   'ec'],
#  ['298', 'El Perdedor - The Remix', 'Maluma', '2159', '2017-01-03', 'ec'],
#  ['299', 'The Scientist', 'Coldplay', '2151', '2017-01-03', 'ec'],
#  ['300', 'Reggaetón Lento (Bailemos)', 'CNCO', '18146', '2017-01-04', 'ec'],
#  ['301', 'Chantaje', 'Shakira', '16582', '2017-01-04', 'ec'],
#  ['302',
#   'Otra Vez (feat. J Balvin)',
#   'Zion & Lennox',
#   '14602',
#   '2017-01-04',
#   'ec'],
#  ['303', "Vente Pa' Ca", 'Ricky Martin', '12413', '2017-01-04', 'ec'],
#  ['304', 'Safari', 'J Balvin', '12386', '2017-01-04', 'ec'],
#  ['305', 'Let Me Love You', 'DJ Snake', '11303', '2017-01-04', 'ec'],
#  ['306', 'Ay Mi Dios', 'IAmChino', '10134', '2017-01-04', 'ec'],
#  ['307', 'Closer', 'The Chainsmokers', '9747', '2017-01-04', 'ec'],
#  ['308', 'Vacaciones', 'Wisin', '9544', '2017-01-04', 'ec'],
#  ['309', 'Traicionera', 'Sebastian Yatra', '9073', '2017-01-04', 'ec'],
#  ['310', 'Starboy', 'The Weeknd', '8903', '2017-01-04', 'ec'],
#  ['311', 'Dile Que Tu Me Quieres', 'Ozuna', '8808', '2017-01-04', 'ec'],
#  ['312', "Don't Wanna Know", 'Maroon 5', '8241', '2017-01-04', 'ec'],
#  ['313', '24K Magic', 'Bruno Mars', '7978', '2017-01-04', 'ec'],
#  ['314', 'One Dance', 'Drake', '7901', '2017-01-04', 'ec'],
#  ['315', 'La Bicicleta', 'Carlos Vives', '7794', '2017-01-04', 'ec'],
#  ['316', 'Chillax', 'Farruko', '7708', '2017-01-04', 'ec'],
#  ['317', 'Andas En Mi Cabeza', 'Chino & Nacho', '7621', '2017-01-04', 'ec'],
#  ['318', 'My Way', 'Calvin Harris', '7338', '2017-01-04', 'ec'],
#  ['319', 'Cuatro Babys', 'Maluma', '7116', '2017-01-04', 'ec'],
#  ['320',
#   'Cold Water (feat. Justin Bieber & MØ)',
#   'Major Lazer',
#   '6856',
#   '2017-01-04',
#   'ec'],
#  ['321',
#   'Me Llamas (feat. Maluma) - Remix',
#   'Piso 21',
#   '6757',
#   '2017-01-04',
#   'ec'],
#  ['322', 'Shaky Shaky', 'Daddy Yankee', '6700', '2017-01-04', 'ec'],
#  ['323',
#   "We Don't Talk Anymore (feat. Selena Gomez)",
#   'Charlie Puth',
#   '6466',
#   '2017-01-04',
#   'ec'],
#  ['324', 'In the Name of Love', 'Martin Garrix', '6358', '2017-01-04', 'ec'],
#  ['325',
#   'Rockabye (feat. Sean Paul & Anne-Marie)',
#   'Clean Bandit',
#   '6240',
#   '2017-01-04',
#   'ec'],
#  ['326',
#   'I Took A Pill In Ibiza - Seeb Remix',
#   'Mike Posner',
#   '6153',
#   '2017-01-04',
#   'ec'],
#  ['327', 'DUELE EL CORAZON', 'Enrique Iglesias', '5814', '2017-01-04', 'ec'],
#  ['328', 'Bailame Despacio', 'Xantos', '5798', '2017-01-04', 'ec'],
#  ['329', 'I Feel It Coming', 'The Weeknd', '5772', '2017-01-04', 'ec'],
#  ['330', 'Borro Cassette', 'Maluma', '5706', '2017-01-04', 'ec'],
#  ['331', "Don't Let Me Down", 'The Chainsmokers', '5623', '2017-01-04', 'ec'],
#  ['332', 'Treat You Better', 'Shawn Mendes', '5445', '2017-01-04', 'ec'],
#  ['333',
#   'Gyal You A Party Animal - Remix',
#   'Charly Black',
#   '5429',
#   '2017-01-04',
#   'ec'],
#  ['334',
#   '"CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s ""TROLLS"")"',
#   'Justin Timberlake',
#   '5272',
#   '2017-01-04',
#   'ec'],
#  ['335', 'Cheap Thrills', 'Sia', '5137', '2017-01-04', 'ec'],
#  ['336',
#   'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#   'Reik',
#   '5100',
#   '2017-01-04',
#   'ec'],
#  ['337', 'Side To Side', 'Ariana Grande', '4993', '2017-01-04', 'ec'],
#  ['338', 'Te Quiero Pa´Mi', 'Don Omar', '4791', '2017-01-04', 'ec'],
#  ['339', 'Desde Esa Noche', 'Thalía', '4742', '2017-01-04', 'ec'],
#  ['340', 'Heathens', 'Twenty One Pilots', '4699', '2017-01-04', 'ec'],
#  ['341', 'Baila Conmigo', 'Juan Magán', '4686', '2017-01-04', 'ec'],
#  ['342', 'Bobo', 'J Balvin', '4557', '2017-01-04', 'ec'],
#  ['343', 'Fuego', 'Juanes', '4483', '2017-01-04', 'ec'],
#  ['345', 'Tan Fácil', 'CNCO', '4289', '2017-01-04', 'ec'],
#  ['346',
#   'This Is What You Came For',
#   'Calvin Harris',
#   '4236',
#   '2017-01-04',
#   'ec'],
#  ['347',
#   'Gyal You A Party Animal',
#   'Charly Black',
#   '4219',
#   '2017-01-04',
#   'ec'],
#  ['348', 'La Gozadera', 'Gente De Zona', '4105', '2017-01-04', 'ec'],
#  ['349', 'Te Vas', 'Ozuna', '4103', '2017-01-04', 'ec'],
#  ['350', 'Hasta el Amanecer', 'Nicky Jam', '3974', '2017-01-04', 'ec'],
#  ['351', 'Photograph', 'Ed Sheeran', '3566', '2017-01-04', 'ec'],
#  ['352',
#   '"I Don’t Wanna Live Forever (Fifty Shades Darker) - From ""Fifty Shades Darker (Original Motion Picture Soundtrack)"""',
#   'ZAYN',
#   '3551',
#   '2017-01-04',
#   'ec'],
#  ['353', 'Just Hold On', 'Steve Aoki', '3445', '2017-01-04', 'ec'],
#  ['354', 'Ride', 'Twenty One Pilots', '3420', '2017-01-04', 'ec'],
#  ['355', 'Ruleta Rusa', 'Kevin Roldan', '3405', '2017-01-04', 'ec'],
#  ['356', 'Cake By The Ocean', 'DNCE', '3344', '2017-01-04', 'ec'],
#  ['357', 'Manicomio', 'Cosculluela', '3336', '2017-01-04', 'ec'],
#  ['358', 'Work from Home', 'Fifth Harmony', '3327', '2017-01-04', 'ec'],
#  ['359',
#   'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#   'Ozuna',
#   '3257',
#   '2017-01-04',
#   'ec'],
#  ['360', 'Deja Que Te Bese', 'Alejandro Sanz', '3243', '2017-01-04', 'ec'],
#  ['361', 'Thinking Out Loud', 'Ed Sheeran', '3211', '2017-01-04', 'ec'],
#  ['362',
#   'Por Fin Te Encontré',
#   'Cali Y El Dandee',
#   '3158',
#   '2017-01-04',
#   'ec'],
#  ['363',
#   'Hymn For The Weekend - Seeb Remix',
#   'Coldplay',
#   '3141',
#   '2017-01-04',
#   'ec'],
#  ['364', 'Work', 'Rihanna', '3090', '2017-01-04', 'ec'],
#  ['365', 'Faded', 'Alan Walker', '3074', '2017-01-04', 'ec'],
#  ['366', 'Stressed Out', 'Twenty One Pilots', '3060', '2017-01-04', 'ec'],
#  ['367', 'Enamorándonos', 'Cabas', '2986', '2017-01-04', 'ec'],
#  ['368', 'Una y otra vez', 'Manuel Medrano', '2969', '2017-01-04', 'ec'],
#  ['369', 'Me Rehúso', 'Danny Ocean', '2949', '2017-01-04', 'ec'],
#  ['370', 'Bajo el agua', 'Manuel Medrano', '2944', '2017-01-04', 'ec'],
#  ['371', "Say You Won't Let Go", 'James Arthur', '2940', '2017-01-04', 'ec'],
#  ['372', 'Que Raro', 'Feid', '2891', '2017-01-04', 'ec'],
#  ['373', 'Love Yourself', 'Justin Bieber', '2873', '2017-01-04', 'ec'],
#  ['375',
#   'Hasta Que Se Seque el Malecón - Remix',
#   'Jacob Forever',
#   '2843',
#   '2017-01-04',
#   'ec'],
#  ['376', 'El Chisme', 'Reykon', '2838', '2017-01-04', 'ec'],
#  ['377', 'Ya Me Enteré', 'Reik', '2814', '2017-01-04', 'ec'],
#  ['378',
#   'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#   'Major Lazer',
#   '2782',
#   '2017-01-04',
#   'ec'],
#  ['379', 'Encantadora - Remix', 'Yandel', '2757', '2017-01-04', 'ec'],
#  ['380', 'All We Know', 'The Chainsmokers', '2713', '2017-01-04', 'ec'],
#  ['381', 'Mercy', 'Shawn Mendes', '2679', '2017-01-04', 'ec'],
#  ['382', 'Perfect Strangers', 'Jonas Blue', '2665', '2017-01-04', 'ec'],
#  ['383', 'Quisiera', 'CNCO', '2644', '2017-01-04', 'ec'],
#  ['384', 'Traicionera - Remix', 'Sebastian Yatra', '2644', '2017-01-04', 'ec'],
#  ['385', 'By Your Side', 'Jonas Blue', '2620', '2017-01-04', 'ec'],
#  ['386',
#   'Mi Tesoro (feat. Nicky Jam)',
#   'Zion & Lennox',
#   '2605',
#   '2017-01-04',
#   'ec'],
#  ['387', 'Starving', 'Hailee Steinfeld', '2534', '2017-01-04', 'ec'],
#  ['388', 'Hear Me Now', 'Alok', '2518', '2017-01-04', 'ec'],
#  ['389',
#   'Call On Me - Ryan Riback Extended Remix',
#   'Starley',
#   '2503',
#   '2017-01-04',
#   'ec'],
#  ['391', 'Black Beatles', 'Rae Sremmurd', '2495', '2017-01-04', 'ec'],
#  ['392',
#   'Corazon De Seda (feat. Ozuna)',
#   'Klasico',
#   '2489',
#   '2017-01-04',
#   'ec'],
#  ['393', 'Fake Love', 'Drake', '2455', '2017-01-04', 'ec'],
#  ['394',
#   'Quiero Que Vuelvas',
#   'Alejandro Fernandez',
#   '2436',
#   '2017-01-04',
#   'ec'],
#  ['395', 'The Greatest', 'Sia', '2417', '2017-01-04', 'ec'],
#  ['396', 'Middle', 'DJ Snake', '2338', '2017-01-04', 'ec'],
#  ['397', 'Shed a Light', 'Robin Schulz', '2318', '2017-01-04', 'ec'],
#  ['398', 'Para Enamorarte', 'CNCO', '2305', '2017-01-04', 'ec'],
#  ['399', 'Me Ama Me Odia', 'Ozuna', '2292', '2017-01-04', 'ec'],
#  ['400', 'Reggaetón Lento (Bailemos)', 'CNCO', '17788', '2017-01-05', 'ec'],
#  ['401', 'Chantaje', 'Shakira', '16254', '2017-01-05', 'ec'],
#  ['402',
#   'Otra Vez (feat. J Balvin)',
#   'Zion & Lennox',
#   '14529',
#   '2017-01-05',
#   'ec'],
#  ['403', "Vente Pa' Ca", 'Ricky Martin', '12337', '2017-01-05', 'ec'],
#  ['404', 'Safari', 'J Balvin', '12102', '2017-01-05', 'ec'],
#  ['405', 'Let Me Love You', 'DJ Snake', '10765', '2017-01-05', 'ec'],
#  ['406', 'Ay Mi Dios', 'IAmChino', '10379', '2017-01-05', 'ec'],
#  ['407', 'Vacaciones', 'Wisin', '9666', '2017-01-05', 'ec'],
#  ['408', 'Closer', 'The Chainsmokers', '9384', '2017-01-05', 'ec'],
#  ['409', 'Traicionera', 'Sebastian Yatra', '8874', '2017-01-05', 'ec'],
#  ['410', 'Dile Que Tu Me Quieres', 'Ozuna', '8307', '2017-01-05', 'ec'],
#  ['411', 'Starboy', 'The Weeknd', '8305', '2017-01-05', 'ec'],
#  ['412', "Don't Wanna Know", 'Maroon 5', '8162', '2017-01-05', 'ec'],
#  ['413', 'Chillax', 'Farruko', '7900', '2017-01-05', 'ec'],
#  ['414', 'Cuatro Babys', 'Maluma', '7749', '2017-01-05', 'ec'],
#  ['415', 'La Bicicleta', 'Carlos Vives', '7706', '2017-01-05', 'ec'],
#  ['416', 'My Way', 'Calvin Harris', '7578', '2017-01-05', 'ec'],
#  ['417', 'One Dance', 'Drake', '7569', '2017-01-05', 'ec'],
#  ['418', 'Andas En Mi Cabeza', 'Chino & Nacho', '7523', '2017-01-05', 'ec'],
#  ['419', '24K Magic', 'Bruno Mars', '7399', '2017-01-05', 'ec'],
#  ['420', 'Shaky Shaky', 'Daddy Yankee', '6594', '2017-01-05', 'ec'],
#  ['421',
#   'Me Llamas (feat. Maluma) - Remix',
#   'Piso 21',
#   '6483',
#   '2017-01-05',
#   'ec'],
#  ['422',
#   'Cold Water (feat. Justin Bieber & MØ)',
#   'Major Lazer',
#   '6360',
#   '2017-01-05',
#   'ec'],
#  ['423', 'In the Name of Love', 'Martin Garrix', '6279', '2017-01-05', 'ec'],
#  ['424',
#   "We Don't Talk Anymore (feat. Selena Gomez)",
#   'Charlie Puth',
#   '6221',
#   '2017-01-05',
#   'ec'],
#  ['425',
#   'Rockabye (feat. Sean Paul & Anne-Marie)',
#   'Clean Bandit',
#   '6107',
#   '2017-01-05',
#   'ec'],
#  ['426',
#   'I Took A Pill In Ibiza - Seeb Remix',
#   'Mike Posner',
#   '5966',
#   '2017-01-05',
#   'ec'],
#  ['427', 'Bailame Despacio', 'Xantos', '5826', '2017-01-05', 'ec'],
#  ['428', 'DUELE EL CORAZON', 'Enrique Iglesias', '5822', '2017-01-05', 'ec'],
#  ['429', 'Borro Cassette', 'Maluma', '5782', '2017-01-05', 'ec'],
#  ['430', 'I Feel It Coming', 'The Weeknd', '5730', '2017-01-05', 'ec'],
#  ['431', 'Treat You Better', 'Shawn Mendes', '5460', '2017-01-05', 'ec'],
#  ['432',
#   'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#   'Reik',
#   '5407',
#   '2017-01-05',
#   'ec'],
#  ['433',
#   'Gyal You A Party Animal - Remix',
#   'Charly Black',
#   '5265',
#   '2017-01-05',
#   'ec'],
#  ['434', "Don't Let Me Down", 'The Chainsmokers', '5106', '2017-01-05', 'ec'],
#  ['435', 'Side To Side', 'Ariana Grande', '5070', '2017-01-05', 'ec'],
#  ['436',
#   '"CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s ""TROLLS"")"',
#   'Justin Timberlake',
#   '5066',
#   '2017-01-05',
#   'ec'],
#  ['437', 'Cheap Thrills', 'Sia', '4922', '2017-01-05', 'ec'],
#  ['438', 'Heathens', 'Twenty One Pilots', '4855', '2017-01-05', 'ec'],
#  ['439', 'Desde Esa Noche', 'Thalía', '4727', '2017-01-05', 'ec'],
#  ['440', 'Bobo', 'J Balvin', '4714', '2017-01-05', 'ec'],
#  ['441',
#   'This Is What You Came For',
#   'Calvin Harris',
#   '4544',
#   '2017-01-05',
#   'ec'],
#  ['442', 'Te Quiero Pa´Mi', 'Don Omar', '4430', '2017-01-05', 'ec'],
#  ['443', 'Baila Conmigo', 'Juan Magán', '4420', '2017-01-05', 'ec'],
#  ['444', 'Fuego', 'Juanes', '4396', '2017-01-05', 'ec'],
#  ['446', 'Tan Fácil', 'CNCO', '4252', '2017-01-05', 'ec'],
#  ['447',
#   'Gyal You A Party Animal',
#   'Charly Black',
#   '4243',
#   '2017-01-05',
#   'ec'],
#  ['448', 'La Gozadera', 'Gente De Zona', '4070', '2017-01-05', 'ec'],
#  ['449', 'Just Hold On', 'Steve Aoki', '4006', '2017-01-05', 'ec'],
#  ['450', 'Te Vas', 'Ozuna', '3998', '2017-01-05', 'ec'],
#  ['451', 'Hasta el Amanecer', 'Nicky Jam', '3700', '2017-01-05', 'ec'],
#  ['452', 'Photograph', 'Ed Sheeran', '3608', '2017-01-05', 'ec'],
#  ['453',
#   '"I Don’t Wanna Live Forever (Fifty Shades Darker) - From ""Fifty Shades Darker (Original Motion Picture Soundtrack)"""',
#   'ZAYN',
#   '3596',
#   '2017-01-05',
#   'ec'],
#  ['454', 'Cake By The Ocean', 'DNCE', '3446', '2017-01-05', 'ec'],
#  ['455', 'Ruleta Rusa', 'Kevin Roldan', '3302', '2017-01-05', 'ec'],
#  ['456', 'Manicomio', 'Cosculluela', '3296', '2017-01-05', 'ec'],
#  ['457', 'Deja Que Te Bese', 'Alejandro Sanz', '3273', '2017-01-05', 'ec'],
#  ['458', 'Thinking Out Loud', 'Ed Sheeran', '3258', '2017-01-05', 'ec'],
#  ['459', 'Faded', 'Alan Walker', '3235', '2017-01-05', 'ec'],
#  ['460', 'Me Rehúso', 'Danny Ocean', '3228', '2017-01-05', 'ec'],
#  ['461', 'Ride', 'Twenty One Pilots', '3180', '2017-01-05', 'ec'],
#  ['462',
#   'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#   'Ozuna',
#   '3119',
#   '2017-01-05',
#   'ec'],
#  ['463', 'Stressed Out', 'Twenty One Pilots', '3084', '2017-01-05', 'ec'],
#  ['464',
#   'Hymn For The Weekend - Seeb Remix',
#   'Coldplay',
#   '3078',
#   '2017-01-05',
#   'ec'],
#  ['465', 'Ya Me Enteré', 'Reik', '3040', '2017-01-05', 'ec'],
#  ['466', 'Una y otra vez', 'Manuel Medrano', '2980', '2017-01-05', 'ec'],
#  ['467',
#   'Por Fin Te Encontré',
#   'Cali Y El Dandee',
#   '2970',
#   '2017-01-05',
#   'ec'],
#  ['468',
#   'Hasta Que Se Seque el Malecón - Remix',
#   'Jacob Forever',
#   '2964',
#   '2017-01-05',
#   'ec'],
#  ['469',
#   'Call On Me - Ryan Riback Extended Remix',
#   'Starley',
#   '2960',
#   '2017-01-05',
#   'ec'],
#  ['471', 'Work from Home', 'Fifth Harmony', '2923', '2017-01-05', 'ec'],
#  ['472', 'Enamorándonos', 'Cabas', '2919', '2017-01-05', 'ec'],
#  ['473', 'Love Yourself', 'Justin Bieber', '2910', '2017-01-05', 'ec'],
#  ['474', 'Work', 'Rihanna', '2869', '2017-01-05', 'ec'],
#  ['475', 'Bajo el agua', 'Manuel Medrano', '2825', '2017-01-05', 'ec'],
#  ['476', 'Encantadora - Remix', 'Yandel', '2811', '2017-01-05', 'ec'],
#  ['477', 'El Chisme', 'Reykon', '2804', '2017-01-05', 'ec'],
#  ['478', 'Quisiera', 'CNCO', '2799', '2017-01-05', 'ec'],
#  ['479',
#   'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#   'Major Lazer',
#   '2788',
#   '2017-01-05',
#   'ec'],
#  ['480', "Say You Won't Let Go", 'James Arthur', '2778', '2017-01-05', 'ec'],
#  ['481', 'Hear Me Now', 'Alok', '2748', '2017-01-05', 'ec'],
#  ['482', 'All We Know', 'The Chainsmokers', '2677', '2017-01-05', 'ec'],
#  ['484', 'Que Raro', 'Feid', '2646', '2017-01-05', 'ec'],
#  ['485',
#   'Corazon De Seda (feat. Ozuna)',
#   'Klasico',
#   '2595',
#   '2017-01-05',
#   'ec'],
#  ['486', 'Starving', 'Hailee Steinfeld', '2571', '2017-01-05', 'ec'],
#  ['487',
#   'Mi Tesoro (feat. Nicky Jam)',
#   'Zion & Lennox',
#   '2567',
#   '2017-01-05',
#   'ec'],
#  ['488', 'Shed a Light', 'Robin Schulz', '2541', '2017-01-05', 'ec'],
#  ['489', 'Perfect Strangers', 'Jonas Blue', '2515', '2017-01-05', 'ec'],
#  ['490',
#   'Quiero Que Vuelvas',
#   'Alejandro Fernandez',
#   '2506',
#   '2017-01-05',
#   'ec'],
#  ['491', 'By Your Side', 'Jonas Blue', '2505', '2017-01-05', 'ec'],
#  ['492', 'Black Beatles', 'Rae Sremmurd', '2500', '2017-01-05', 'ec'],
#  ['493', 'Mercy', 'Shawn Mendes', '2475', '2017-01-05', 'ec'],
#  ['494', 'Too Good', 'Drake', '2455', '2017-01-05', 'ec'],
#  ['495', 'The Greatest', 'Sia', '2395', '2017-01-05', 'ec'],
#  ['496', 'Traicionera - Remix', 'Sebastian Yatra', '2395', '2017-01-05', 'ec'],
#  ['497', 'Fake Love', 'Drake', '2389', '2017-01-05', 'ec'],
#  ['498', 'Me Ama Me Odia', 'Ozuna', '2369', '2017-01-05', 'ec'],
#  ['499', 'El Perdedor - The Remix', 'Maluma', '2328', '2017-01-05', 'ec'],
#  ['500', 'Reggaetón Lento (Bailemos)', 'CNCO', '18579', '2017-01-06', 'ec'],
#  ['501', 'Chantaje', 'Shakira', '17215', '2017-01-06', 'ec'],
#  ['502',
#   'Otra Vez (feat. J Balvin)',
#   'Zion & Lennox',
#   '15447',
#   '2017-01-06',
#   'ec'],
#  ['503', "Vente Pa' Ca", 'Ricky Martin', '12770', '2017-01-06', 'ec'],
#  ['504', 'Safari', 'J Balvin', '12766', '2017-01-06', 'ec'],
#  ['505', 'Ay Mi Dios', 'IAmChino', '10841', '2017-01-06', 'ec'],
#  ['506', 'Let Me Love You', 'DJ Snake', '10578', '2017-01-06', 'ec'],
#  ['507', 'Vacaciones', 'Wisin', '10318', '2017-01-06', 'ec'],
#  ['508', 'Traicionera', 'Sebastian Yatra', '9457', '2017-01-06', 'ec'],
#  ['509', 'Closer', 'The Chainsmokers', '9090', '2017-01-06', 'ec'],
#  ['510', 'Dile Que Tu Me Quieres', 'Ozuna', '9089', '2017-01-06', 'ec'],
#  ['511', 'Chillax', 'Farruko', '8255', '2017-01-06', 'ec'],
#  ['512', 'Starboy', 'The Weeknd', '8229', '2017-01-06', 'ec'],
#  ['513', "Don't Wanna Know", 'Maroon 5', '7933', '2017-01-06', 'ec'],
#  ['514', 'La Bicicleta', 'Carlos Vives', '7914', '2017-01-06', 'ec'],
#  ['515', 'Cuatro Babys', 'Maluma', '7746', '2017-01-06', 'ec'],
#  ['516', 'My Way', 'Calvin Harris', '7575', '2017-01-06', 'ec'],
#  ['517', 'Andas En Mi Cabeza', 'Chino & Nacho', '7528', '2017-01-06', 'ec'],
#  ['518', 'One Dance', 'Drake', '7433', '2017-01-06', 'ec'],
#  ['519', '24K Magic', 'Bruno Mars', '7133', '2017-01-06', 'ec'],
#  ['520', 'Shape of You', 'Ed Sheeran', '7099', '2017-01-06', 'ec'],
#  ['521',
#   'Me Llamas (feat. Maluma) - Remix',
#   'Piso 21',
#   '7042',
#   '2017-01-06',
#   'ec'],
#  ['522', 'Shaky Shaky', 'Daddy Yankee', '7010', '2017-01-06', 'ec'],
#  ['523',
#   'Cold Water (feat. Justin Bieber & MØ)',
#   'Major Lazer',
#   '6370',
#   '2017-01-06',
#   'ec'],
#  ['524',
#   'Rockabye (feat. Sean Paul & Anne-Marie)',
#   'Clean Bandit',
#   '6242',
#   '2017-01-06',
#   'ec'],
#  ['525', 'In the Name of Love', 'Martin Garrix', '6083', '2017-01-06', 'ec'],
#  ['526', 'Bailame Despacio', 'Xantos', '6043', '2017-01-06', 'ec'],
#  ['527',
#   "We Don't Talk Anymore (feat. Selena Gomez)",
#   'Charlie Puth',
#   '6034',
#   '2017-01-06',
#   'ec'],
#  ['528', 'DUELE EL CORAZON', 'Enrique Iglesias', '5937', '2017-01-06', 'ec'],
#  ['529', 'Borro Cassette', 'Maluma', '5930', '2017-01-06', 'ec'],
#  ['530', 'Castle on the Hill', 'Ed Sheeran', '5890', '2017-01-06', 'ec'],
#  ['531',
#   'I Took A Pill In Ibiza - Seeb Remix',
#   'Mike Posner',
#   '5808',
#   '2017-01-06',
#   'ec'],
#  ['532',
#   'Gyal You A Party Animal - Remix',
#   'Charly Black',
#   '5690',
#   '2017-01-06',
#   'ec'],
#  ['533',
#   'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#   'Reik',
#   '5674',
#   '2017-01-06',
#   'ec'],
#  ['534', 'I Feel It Coming', 'The Weeknd', '5638', '2017-01-06', 'ec'],
#  ['535', 'Treat You Better', 'Shawn Mendes', '5170', '2017-01-06', 'ec'],
#  ['536', 'Desde Esa Noche', 'Thalía', '5020', '2017-01-06', 'ec'],
#  ['537', "Don't Let Me Down", 'The Chainsmokers', '4980', '2017-01-06', 'ec'],
#  ['538', 'Side To Side', 'Ariana Grande', '4956', '2017-01-06', 'ec'],
#  ['539', 'Cheap Thrills', 'Sia', '4954', '2017-01-06', 'ec'],
#  ['540',
#   '"CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s ""TROLLS"")"',
#   'Justin Timberlake',
#   '4948',
#   '2017-01-06',
#   'ec'],
#  ['541', 'Bobo', 'J Balvin', '4831', '2017-01-06', 'ec'],
#  ['542', 'Te Quiero Pa´Mi', 'Don Omar', '4811', '2017-01-06', 'ec'],
#  ['544', 'Heathens', 'Twenty One Pilots', '4679', '2017-01-06', 'ec'],
#  ['545', 'Baila Conmigo', 'Juan Magán', '4588', '2017-01-06', 'ec'],
#  ['546', 'Fuego', 'Juanes', '4576', '2017-01-06', 'ec'],
#  ['547',
#   'This Is What You Came For',
#   'Calvin Harris',
#   '4564',
#   '2017-01-06',
#   'ec'],
#  ['548', 'Tan Fácil', 'CNCO', '4548', '2017-01-06', 'ec'],
#  ['549',
#   'Gyal You A Party Animal',
#   'Charly Black',
#   '4520',
#   '2017-01-06',
#   'ec'],
#  ['550', 'La Gozadera', 'Gente De Zona', '4328', '2017-01-06', 'ec'],
#  ['551', 'Te Vas', 'Ozuna', '4164', '2017-01-06', 'ec'],
#  ['552', 'Photograph', 'Ed Sheeran', '4138', '2017-01-06', 'ec'],
#  ['553', 'Hasta el Amanecer', 'Nicky Jam', '3738', '2017-01-06', 'ec'],
#  ['554', 'Just Hold On', 'Steve Aoki', '3699', '2017-01-06', 'ec'],
#  ['555',
#   '"I Don’t Wanna Live Forever (Fifty Shades Darker) - From ""Fifty Shades Darker (Original Motion Picture Soundtrack)"""',
#   'ZAYN',
#   '3552',
#   '2017-01-06',
#   'ec'],
#  ['556', 'Manicomio', 'Cosculluela', '3543', '2017-01-06', 'ec'],
#  ['557',
#   'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#   'Ozuna',
#   '3538',
#   '2017-01-06',
#   'ec'],
#  ['558', 'Thinking Out Loud', 'Ed Sheeran', '3460', '2017-01-06', 'ec'],
#  ['559', 'Me Rehúso', 'Danny Ocean', '3456', '2017-01-06', 'ec'],
#  ['560', 'Deja Que Te Bese', 'Alejandro Sanz', '3399', '2017-01-06', 'ec'],
#  ['561', 'Ruleta Rusa', 'Kevin Roldan', '3384', '2017-01-06', 'ec'],
#  ['563', 'Cake By The Ocean', 'DNCE', '3269', '2017-01-06', 'ec'],
#  ['564',
#   'Por Fin Te Encontré',
#   'Cali Y El Dandee',
#   '3222',
#   '2017-01-06',
#   'ec'],
#  ['565', 'Faded', 'Alan Walker', '3199', '2017-01-06', 'ec'],
#  ['566',
#   'Hasta Que Se Seque el Malecón - Remix',
#   'Jacob Forever',
#   '3188',
#   '2017-01-06',
#   'ec'],
#  ['567', 'Enamorándonos', 'Cabas', '3097', '2017-01-06', 'ec'],
#  ['568', 'Ride', 'Twenty One Pilots', '3093', '2017-01-06', 'ec'],
#  ['569', 'Stressed Out', 'Twenty One Pilots', '3073', '2017-01-06', 'ec'],
#  ['570', 'El Chisme', 'Reykon', '3059', '2017-01-06', 'ec'],
#  ['571',
#   'Hymn For The Weekend - Seeb Remix',
#   'Coldplay',
#   '3035',
#   '2017-01-06',
#   'ec'],
#  ['572',
#   'Corazon De Seda (feat. Ozuna)',
#   'Klasico',
#   '2995',
#   '2017-01-06',
#   'ec'],
#  ['573', "Say You Won't Let Go", 'James Arthur', '2949', '2017-01-06', 'ec'],
#  ['574', 'Ya Me Enteré', 'Reik', '2903', '2017-01-06', 'ec'],
#  ['575', 'Encantadora - Remix', 'Yandel', '2882', '2017-01-06', 'ec'],
#  ['576', 'Bajo el agua', 'Manuel Medrano', '2870', '2017-01-06', 'ec'],
#  ['577',
#   'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#   'Major Lazer',
#   '2828',
#   '2017-01-06',
#   'ec'],
#  ['578', 'Quisiera', 'CNCO', '2812', '2017-01-06', 'ec'],
#  ['579', 'Una y otra vez', 'Manuel Medrano', '2808', '2017-01-06', 'ec'],
#  ['580',
#   'Call On Me - Ryan Riback Extended Remix',
#   'Starley',
#   '2769',
#   '2017-01-06',
#   'ec'],
#  ['581', 'Work', 'Rihanna', '2741', '2017-01-06', 'ec'],
#  ['582',
#   'Mi Tesoro (feat. Nicky Jam)',
#   'Zion & Lennox',
#   '2726',
#   '2017-01-06',
#   'ec'],
#  ['583', 'Traicionera - Remix', 'Sebastian Yatra', '2707', '2017-01-06', 'ec'],
#  ['585', 'Love Yourself', 'Justin Bieber', '2663', '2017-01-06', 'ec'],
#  ['586', 'Que Raro', 'Feid', '2649', '2017-01-06', 'ec'],
#  ['587', 'Me Ama Me Odia', 'Ozuna', '2612', '2017-01-06', 'ec'],
#  ['588', 'Work from Home', 'Fifth Harmony', '2594', '2017-01-06', 'ec'],
#  ['589', 'Hear Me Now', 'Alok', '2530', '2017-01-06', 'ec'],
#  ['590', 'Perfect Strangers', 'Jonas Blue', '2528', '2017-01-06', 'ec'],
#  ['591', 'El Perdedor - The Remix', 'Maluma', '2525', '2017-01-06', 'ec'],
#  ['592',
#   'Si Me Dices Que Si (feat. Nicky Jam)',
#   'Cosculluela',
#   '2520',
#   '2017-01-06',
#   'ec'],
#  ['593', 'All We Know', 'The Chainsmokers', '2497', '2017-01-06', 'ec'],
#  ['594', 'Black Beatles', 'Rae Sremmurd', '2408', '2017-01-06', 'ec'],
#  ['595', 'By Your Side', 'Jonas Blue', '2406', '2017-01-06', 'ec'],
#  ['596', 'Mercy', 'Shawn Mendes', '2373', '2017-01-06', 'ec'],
#  ['597', 'Shed a Light', 'Robin Schulz', '2357', '2017-01-06', 'ec'],
#  ['598', 'Para Enamorarte', 'CNCO', '2352', '2017-01-06', 'ec'],
#  ['599', 'Encantadora', 'Yandel', '2343', '2017-01-06', 'ec'],
#  ['600', 'Reggaetón Lento (Bailemos)', 'CNCO', '21438', '2017-01-07', 'ec'],
#  ['601', 'Chantaje', 'Shakira', '19357', '2017-01-07', 'ec'],
#  ['602',
#   'Otra Vez (feat. J Balvin)',
#   'Zion & Lennox',
#   '17095',
#   '2017-01-07',
#   'ec'],
#  ['603', 'Safari', 'J Balvin', '14493', '2017-01-07', 'ec'],
#  ['604', "Vente Pa' Ca", 'Ricky Martin', '14144', '2017-01-07', 'ec'],
#  ['605', 'Ay Mi Dios', 'IAmChino', '11781', '2017-01-07', 'ec'],
#  ['606', 'Vacaciones', 'Wisin', '11553', '2017-01-07', 'ec'],
#  ['607', 'Let Me Love You', 'DJ Snake', '10762', '2017-01-07', 'ec'],
#  ['608', 'Dile Que Tu Me Quieres', 'Ozuna', '10552', '2017-01-07', 'ec'],
#  ['609', 'Traicionera', 'Sebastian Yatra', '10335', '2017-01-07', 'ec'],
#  ['610', 'Shape of You', 'Ed Sheeran', '9695', '2017-01-07', 'ec'],
#  ['611', 'Closer', 'The Chainsmokers', '9118', '2017-01-07', 'ec'],
#  ['612', 'La Bicicleta', 'Carlos Vives', '8998', '2017-01-07', 'ec'],
#  ['613', 'Chillax', 'Farruko', '8994', '2017-01-07', 'ec'],
#  ['614', 'Andas En Mi Cabeza', 'Chino & Nacho', '8882', '2017-01-07', 'ec'],
#  ['615', 'Shaky Shaky', 'Daddy Yankee', '8257', '2017-01-07', 'ec'],
#  ['616', 'Cuatro Babys', 'Maluma', '8168', '2017-01-07', 'ec'],
#  ['617', "Don't Wanna Know", 'Maroon 5', '8050', '2017-01-07', 'ec'],
#  ['618', 'Starboy', 'The Weeknd', '8020', '2017-01-07', 'ec'],
#  ['619',
#   'Me Llamas (feat. Maluma) - Remix',
#   'Piso 21',
#   '7719',
#   '2017-01-07',
#   'ec'],
#  ['620', '24K Magic', 'Bruno Mars', '7714', '2017-01-07', 'ec'],
#  ['621', 'One Dance', 'Drake', '7502', '2017-01-07', 'ec'],
#  ['622', 'My Way', 'Calvin Harris', '7396', '2017-01-07', 'ec'],
#  ['623', 'Borro Cassette', 'Maluma', '6706', '2017-01-07', 'ec'],
#  ['624', 'Bailame Despacio', 'Xantos', '6553', '2017-01-07', 'ec'],
#  ['625', 'DUELE EL CORAZON', 'Enrique Iglesias', '6483', '2017-01-07', 'ec'],
#  ['626',
#   'Cold Water (feat. Justin Bieber & MØ)',
#   'Major Lazer',
#   '6356',
#   '2017-01-07',
#   'ec'],
#  ['627',
#   'Rockabye (feat. Sean Paul & Anne-Marie)',
#   'Clean Bandit',
#   '6350',
#   '2017-01-07',
#   'ec'],
#  ['628',
#   'Gyal You A Party Animal - Remix',
#   'Charly Black',
#   '6343',
#   '2017-01-07',
#   'ec'],
#  ['629', 'In the Name of Love', 'Martin Garrix', '6199', '2017-01-07', 'ec'],
#  ['630', 'Castle on the Hill', 'Ed Sheeran', '6079', '2017-01-07', 'ec'],
#  ['631',
#   "We Don't Talk Anymore (feat. Selena Gomez)",
#   'Charlie Puth',
#   '6039',
#   '2017-01-07',
#   'ec'],
#  ['632',
#   'I Took A Pill In Ibiza - Seeb Remix',
#   'Mike Posner',
#   '5896',
#   '2017-01-07',
#   'ec'],
#  ['633',
#   'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#   'Reik',
#   '5602',
#   '2017-01-07',
#   'ec'],
#  ['634', 'I Feel It Coming', 'The Weeknd', '5563', '2017-01-07', 'ec'],
#  ['635', 'Desde Esa Noche', 'Thalía', '5559', '2017-01-07', 'ec'],
#  ['636', 'Te Quiero Pa´Mi', 'Don Omar', '5307', '2017-01-07', 'ec'],
#  ['637', 'Bobo', 'J Balvin', '5150', '2017-01-07', 'ec'],
#  ['638', 'Treat You Better', 'Shawn Mendes', '5131', '2017-01-07', 'ec'],
#  ['640', 'Side To Side', 'Ariana Grande', '5129', '2017-01-07', 'ec'],
#  ['641', "Don't Let Me Down", 'The Chainsmokers', '5044', '2017-01-07', 'ec'],
#  ['642',
#   '"CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s ""TROLLS"")"',
#   'Justin Timberlake',
#   '5028',
#   '2017-01-07',
#   'ec'],
#  ['643', 'Cheap Thrills', 'Sia', '4980', '2017-01-07', 'ec'],
#  ['644', 'Tan Fácil', 'CNCO', '4880', '2017-01-07', 'ec'],
#  ['645', 'Baila Conmigo', 'Juan Magán', '4869', '2017-01-07', 'ec'],
#  ['646',
#   'Gyal You A Party Animal',
#   'Charly Black',
#   '4831',
#   '2017-01-07',
#   'ec'],
#  ['647', 'Heathens', 'Twenty One Pilots', '4778', '2017-01-07', 'ec'],
#  ['648', 'Fuego', 'Juanes', '4682', '2017-01-07', 'ec'],
#  ['649', 'La Gozadera', 'Gente De Zona', '4652', '2017-01-07', 'ec'],
#  ['650',
#   'This Is What You Came For',
#   'Calvin Harris',
#   '4367',
#   '2017-01-07',
#   'ec'],
#  ['651', 'Te Vas', 'Ozuna', '4307', '2017-01-07', 'ec'],
#  ['652', 'Hasta el Amanecer', 'Nicky Jam', '4094', '2017-01-07', 'ec'],
# ...
#  ['811', 'Closer', 'The Chainsmokers', '8146', '2017-01-09', 'ec'],
#  ['812', 'Chillax', 'Farruko', '7679', '2017-01-09', 'ec'],
#  ['813', 'Starboy', 'The Weeknd', '7568', '2017-01-09', 'ec'],
#  ['814', "Don't Wanna Know", 'Maroon 5', '7442', '2017-01-09', 'ec'],
#  ['815', 'Andas En Mi Cabeza', 'Chino & Nacho', '7134', '2017-01-09', 'ec'],
#  ['816', 'La Bicicleta', 'Carlos Vives', '7125', '2017-01-09', 'ec'],
#  ['817', '24K Magic', 'Bruno Mars', '6925', '2017-01-09', 'ec'],
#  ['818', 'One Dance', 'Drake', '6780', '2017-01-09', 'ec'],
#  ['819', 'Cuatro Babys', 'Maluma', '6688', '2017-01-09', 'ec'],
#  ['820',
#   'Me Llamas (feat. Maluma) - Remix',
#   'Piso 21',
#   '6567',
#   '2017-01-09',
#   'ec'],
#  ['821', 'Shaky Shaky', 'Daddy Yankee', '6375', '2017-01-09', 'ec'],
#  ['822', 'My Way', 'Calvin Harris', '6368', '2017-01-09', 'ec'],
#  ['823',
#   'Rockabye (feat. Sean Paul & Anne-Marie)',
#   'Clean Bandit',
#   '6049',
#   '2017-01-09',
#   'ec'],
#  ['824', 'Castle on the Hill', 'Ed Sheeran', '5851', '2017-01-09', 'ec'],
#  ['825',
#   'Cold Water (feat. Justin Bieber & MØ)',
#   'Major Lazer',
#   '5806',
#   '2017-01-09',
#   'ec'],
#  ['826', 'I Feel It Coming', 'The Weeknd', '5741', '2017-01-09', 'ec'],
#  ['827', 'In the Name of Love', 'Martin Garrix', '5533', '2017-01-09', 'ec'],
#  ['828',
#   "We Don't Talk Anymore (feat. Selena Gomez)",
#   'Charlie Puth',
#   '5525',
#   '2017-01-09',
#   'ec'],
#  ['829', 'Borro Cassette', 'Maluma', '5415', '2017-01-09', 'ec'],
#  ['830',
#   'I Took A Pill In Ibiza - Seeb Remix',
#   'Mike Posner',
#   '5388',
#   '2017-01-09',
#   'ec'],
#  ['831', 'Bailame Despacio', 'Xantos', '5312', '2017-01-09', 'ec'],
#  ['832', 'DUELE EL CORAZON', 'Enrique Iglesias', '5126', '2017-01-09', 'ec'],
#  ['833',
#   'Gyal You A Party Animal - Remix',
#   'Charly Black',
#   '4968',
#   '2017-01-09',
#   'ec'],
#  ['834', 'Side To Side', 'Ariana Grande', '4883', '2017-01-09', 'ec'],
#  ['835', 'Te Quiero Pa´Mi', 'Don Omar', '4721', '2017-01-09', 'ec'],
#  ['836', 'Treat You Better', 'Shawn Mendes', '4710', '2017-01-09', 'ec'],
#  ['837',
#   'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#   'Reik',
#   '4668',
#   '2017-01-09',
#   'ec'],
#  ['838', 'Photograph', 'Ed Sheeran', '4627', '2017-01-09', 'ec'],
#  ['839', 'Desde Esa Noche', 'Thalía', '4603', '2017-01-09', 'ec'],
#  ['840', "Don't Let Me Down", 'The Chainsmokers', '4486', '2017-01-09', 'ec'],
#  ['841', 'Cheap Thrills', 'Sia', '4476', '2017-01-09', 'ec'],
#  ['843', 'Heathens', 'Twenty One Pilots', '4421', '2017-01-09', 'ec'],
#  ['844',
#   '"CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s ""TROLLS"")"',
#   'Justin Timberlake',
#   '4377',
#   '2017-01-09',
#   'ec'],
#  ['845', 'Bobo', 'J Balvin', '4264', '2017-01-09', 'ec'],
#  ['846', 'Fuego', 'Juanes', '4232', '2017-01-09', 'ec'],
#  ['847',
#   'Gyal You A Party Animal',
#   'Charly Black',
#   '4125',
#   '2017-01-09',
#   'ec'],
#  ['848', 'Tan Fácil', 'CNCO', '3907', '2017-01-09', 'ec'],
#  ['849',
#   '"I Don’t Wanna Live Forever (Fifty Shades Darker) - From ""Fifty Shades Darker (Original Motion Picture Soundtrack)"""',
#   'ZAYN',
#   '3875',
#   '2017-01-09',
#   'ec'],
#  ['850', 'Baila Conmigo', 'Juan Magán', '3856', '2017-01-09', 'ec'],
#  ['851', 'La Gozadera', 'Gente De Zona', '3841', '2017-01-09', 'ec'],
#  ['852', 'Just Hold On', 'Steve Aoki', '3608', '2017-01-09', 'ec'],
#  ['853', 'Te Vas', 'Ozuna', '3521', '2017-01-09', 'ec'],
#  ['854',
#   'This Is What You Came For',
#   'Calvin Harris',
#   '3498',
#   '2017-01-09',
#   'ec'],
#  ['855', 'Hasta el Amanecer', 'Nicky Jam', '3424', '2017-01-09', 'ec'],
#  ['856', 'Deja Que Te Bese', 'Alejandro Sanz', '3302', '2017-01-09', 'ec'],
#  ['857', "Say You Won't Let Go", 'James Arthur', '3289', '2017-01-09', 'ec'],
#  ['858', 'Manicomio', 'Cosculluela', '3283', '2017-01-09', 'ec'],
#  ['859', 'Ruleta Rusa', 'Kevin Roldan', '3235', '2017-01-09', 'ec'],
#  ['860', 'Me Rehúso', 'Danny Ocean', '3181', '2017-01-09', 'ec'],
#  ['861', 'Thinking Out Loud', 'Ed Sheeran', '3137', '2017-01-09', 'ec'],
#  ['862',
#   'Si Me Dices Que Si (feat. Nicky Jam)',
#   'Cosculluela',
#   '3109',
#   '2017-01-09',
#   'ec'],
#  ['864',
#   'Por Fin Te Encontré',
#   'Cali Y El Dandee',
#   '3040',
#   '2017-01-09',
#   'ec'],
#  ['865',
#   'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#   'Ozuna',
#   '3037',
#   '2017-01-09',
#   'ec'],
#  ['866', 'Faded', 'Alan Walker', '2962', '2017-01-09', 'ec'],
#  ['867', 'Bajo el agua', 'Manuel Medrano', '2910', '2017-01-09', 'ec'],
#  ['868',
#   'Hasta Que Se Seque el Malecón - Remix',
#   'Jacob Forever',
#   '2896',
#   '2017-01-09',
#   'ec'],
#  ['869', 'Ride', 'Twenty One Pilots', '2888', '2017-01-09', 'ec'],
#  ['870', 'Cake By The Ocean', 'DNCE', '2861', '2017-01-09', 'ec'],
#  ['871',
#   'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#   'Major Lazer',
#   '2850',
#   '2017-01-09',
#   'ec'],
#  ['872', 'Ya Me Enteré', 'Reik', '2841', '2017-01-09', 'ec'],
#  ['873', 'Mercy', 'Shawn Mendes', '2815', '2017-01-09', 'ec'],
#  ['874', 'Una y otra vez', 'Manuel Medrano', '2815', '2017-01-09', 'ec'],
#  ['875', 'El Chisme', 'Reykon', '2814', '2017-01-09', 'ec'],
#  ['876', 'Stressed Out', 'Twenty One Pilots', '2809', '2017-01-09', 'ec'],
#  ['877', 'Enamorándonos', 'Cabas', '2808', '2017-01-09', 'ec'],
#  ['878',
#   'Call On Me - Ryan Riback Extended Remix',
#   'Starley',
#   '2715',
#   '2017-01-09',
#   'ec'],
#  ['879', 'Dueles', 'Jesse & Joy', '2703', '2017-01-09', 'ec'],
#  ['880',
#   'Hymn For The Weekend - Seeb Remix',
#   'Coldplay',
#   '2678',
#   '2017-01-09',
#   'ec'],
#  ['881', 'Work', 'Rihanna', '2649', '2017-01-09', 'ec'],
#  ['882', 'Hear Me Now', 'Alok', '2648', '2017-01-09', 'ec'],
#  ['883', 'By Your Side', 'Jonas Blue', '2612', '2017-01-09', 'ec'],
#  ['884', 'Quisiera', 'CNCO', '2605', '2017-01-09', 'ec'],
#  ['885', 'All We Know', 'The Chainsmokers', '2583', '2017-01-09', 'ec'],
#  ['886',
#   'Mi Tesoro (feat. Nicky Jam)',
#   'Zion & Lennox',
#   '2568',
#   '2017-01-09',
#   'ec'],
#  ['887', 'Traicionera - Remix', 'Sebastian Yatra', '2560', '2017-01-09', 'ec'],
#  ['888', 'Que Raro', 'Feid', '2549', '2017-01-09', 'ec'],
#  ['889', 'Love Yourself', 'Justin Bieber', '2537', '2017-01-09', 'ec'],
#  ['890', 'Encantadora - Remix', 'Yandel', '2523', '2017-01-09', 'ec'],
#  ['891', 'Shed a Light', 'Robin Schulz', '2514', '2017-01-09', 'ec'],
#  ['892', 'The Scientist', 'Coldplay', '2484', '2017-01-09', 'ec'],
#  ['893', 'Me Ama Me Odia', 'Ozuna', '2414', '2017-01-09', 'ec'],
#  ['894', 'Alone', 'Alan Walker', '2392', '2017-01-09', 'ec'],
#  ['895', 'Fake Love', 'Drake', '2383', '2017-01-09', 'ec'],
#  ['896', 'Soy Peor', 'Bad Bunny', '2366', '2017-01-09', 'ec'],
#  ['897', 'Work from Home', 'Fifth Harmony', '2339', '2017-01-09', 'ec'],
#  ['898',
#   'Quiero Que Vuelvas',
#   'Alejandro Fernandez',
#   '2298',
#   '2017-01-09',
#   'ec'],
#  ['899',
#   'Corazon De Seda (feat. Ozuna)',
#   'Klasico',
#   '2295',
#   '2017-01-09',
#   'ec'],
#  ['900', 'Reggaetón Lento (Bailemos)', 'CNCO', '16595', '2017-01-10', 'ec'],
#  ['901', 'Chantaje', 'Shakira', '14851', '2017-01-10', 'ec'],
#  ['902',
#   'Otra Vez (feat. J Balvin)',
#   'Zion & Lennox',
#   '12774',
#   '2017-01-10',
#   'ec'],
#  ['903', 'Shape of You', 'Ed Sheeran', '12360', '2017-01-10', 'ec'],
#  ['904', 'Safari', 'J Balvin', '11212', '2017-01-10', 'ec'],
#  ['905', "Vente Pa' Ca", 'Ricky Martin', '10633', '2017-01-10', 'ec'],
#  ['906', 'Let Me Love You', 'DJ Snake', '10042', '2017-01-10', 'ec'],
#  ['907', 'Ay Mi Dios', 'IAmChino', '9296', '2017-01-10', 'ec'],
#  ['908', 'Vacaciones', 'Wisin', '9099', '2017-01-10', 'ec'],
#  ['909', 'Traicionera', 'Sebastian Yatra', '8411', '2017-01-10', 'ec'],
#  ['910', 'Closer', 'The Chainsmokers', '8357', '2017-01-10', 'ec'],
#  ['911', 'Dile Que Tu Me Quieres', 'Ozuna', '8068', '2017-01-10', 'ec'],
#  ['912', 'Starboy', 'The Weeknd', '7986', '2017-01-10', 'ec'],
#  ['913', "Don't Wanna Know", 'Maroon 5', '7953', '2017-01-10', 'ec'],
#  ['914', 'Chillax', 'Farruko', '7256', '2017-01-10', 'ec'],
#  ['915', '24K Magic', 'Bruno Mars', '7038', '2017-01-10', 'ec'],
#  ['916', 'La Bicicleta', 'Carlos Vives', '6931', '2017-01-10', 'ec'],
#  ['917', 'My Way', 'Calvin Harris', '6900', '2017-01-10', 'ec'],
#  ['918', 'Andas En Mi Cabeza', 'Chino & Nacho', '6763', '2017-01-10', 'ec'],
#  ['919', 'One Dance', 'Drake', '6702', '2017-01-10', 'ec'],
#  ['920', 'Cuatro Babys', 'Maluma', '6562', '2017-01-10', 'ec'],
#  ['921',
#   'Me Llamas (feat. Maluma) - Remix',
#   'Piso 21',
#   '6279',
#   '2017-01-10',
#   'ec'],
#  ['922',
#   'Rockabye (feat. Sean Paul & Anne-Marie)',
#   'Clean Bandit',
#   '6221',
#   '2017-01-10',
#   'ec'],
#  ['923', 'Castle on the Hill', 'Ed Sheeran', '6071', '2017-01-10', 'ec'],
#  ['924', 'Shaky Shaky', 'Daddy Yankee', '5946', '2017-01-10', 'ec'],
#  ['925', 'I Feel It Coming', 'The Weeknd', '5945', '2017-01-10', 'ec'],
#  ['926',
#   "We Don't Talk Anymore (feat. Selena Gomez)",
#   'Charlie Puth',
#   '5816',
#   '2017-01-10',
#   'ec'],
#  ['927',
#   'Cold Water (feat. Justin Bieber & MØ)',
#   'Major Lazer',
#   '5752',
#   '2017-01-10',
#   'ec'],
#  ['928', 'In the Name of Love', 'Martin Garrix', '5616', '2017-01-10', 'ec'],
#  ['929',
#   'I Took A Pill In Ibiza - Seeb Remix',
#   'Mike Posner',
#   '5542',
#   '2017-01-10',
#   'ec'],
#  ['930', 'Side To Side', 'Ariana Grande', '5175', '2017-01-10', 'ec'],
#  ['931', 'Bailame Despacio', 'Xantos', '5081', '2017-01-10', 'ec'],
#  ['932', 'Treat You Better', 'Shawn Mendes', '5007', '2017-01-10', 'ec'],
#  ['933', 'Borro Cassette', 'Maluma', '4995', '2017-01-10', 'ec'],
#  ['934', 'Photograph', 'Ed Sheeran', '4922', '2017-01-10', 'ec'],
#  ['935', 'DUELE EL CORAZON', 'Enrique Iglesias', '4868', '2017-01-10', 'ec'],
#  ['936',
#   'Gyal You A Party Animal - Remix',
#   'Charly Black',
#   '4737',
#   '2017-01-10',
#   'ec'],
#  ['937',
#   'Ya Me Enteré (feat. Nicky Jam) - Urban Version',
#   'Reik',
#   '4673',
#   '2017-01-10',
#   'ec'],
#  ['938', 'Cheap Thrills', 'Sia', '4633', '2017-01-10', 'ec'],
#  ['939', "Don't Let Me Down", 'The Chainsmokers', '4540', '2017-01-10', 'ec'],
#  ['940', 'Te Quiero Pa´Mi', 'Don Omar', '4526', '2017-01-10', 'ec'],
#  ['941', 'Heathens', 'Twenty One Pilots', '4490', '2017-01-10', 'ec'],
#  ['943',
#   '"I Don’t Wanna Live Forever (Fifty Shades Darker) - From ""Fifty Shades Darker (Original Motion Picture Soundtrack)"""',
#   'ZAYN',
#   '4404',
#   '2017-01-10',
#   'ec'],
#  ['944',
#   '"CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s ""TROLLS"")"',
#   'Justin Timberlake',
#   '4404',
#   '2017-01-10',
#   'ec'],
#  ['945', 'Desde Esa Noche', 'Thalía', '4348', '2017-01-10', 'ec'],
#  ['946', 'Bobo', 'J Balvin', '4079', '2017-01-10', 'ec'],
#  ['947', 'Tan Fácil', 'CNCO', '4067', '2017-01-10', 'ec'],
#  ['948', 'Fuego', 'Juanes', '3909', '2017-01-10', 'ec'],
#  ['949',
#   'Gyal You A Party Animal',
#   'Charly Black',
#   '3888',
#   '2017-01-10',
#   'ec'],
#  ['950',
#   'This Is What You Came For',
#   'Calvin Harris',
#   '3684',
#   '2017-01-10',
#   'ec'],
#  ['951', 'Just Hold On', 'Steve Aoki', '3649', '2017-01-10', 'ec'],
#  ['952', 'Thinking Out Loud', 'Ed Sheeran', '3474', '2017-01-10', 'ec'],
#  ['953', 'La Gozadera', 'Gente De Zona', '3445', '2017-01-10', 'ec'],
#  ['954', 'Baila Conmigo', 'Juan Magán', '3426', '2017-01-10', 'ec'],
#  ['955', 'Me Rehúso', 'Danny Ocean', '3343', '2017-01-10', 'ec'],
#  ['956', 'Te Vas', 'Ozuna', '3199', '2017-01-10', 'ec'],
#  ['957', "Say You Won't Let Go", 'James Arthur', '3165', '2017-01-10', 'ec'],
#  ['958', 'Manicomio', 'Cosculluela', '3118', '2017-01-10', 'ec'],
#  ['959', 'Faded', 'Alan Walker', '3105', '2017-01-10', 'ec'],
#  ['960', 'Cake By The Ocean', 'DNCE', '3100', '2017-01-10', 'ec'],
#  ['961', 'Stressed Out', 'Twenty One Pilots', '3097', '2017-01-10', 'ec'],
#  ['962', 'Deja Que Te Bese', 'Alejandro Sanz', '3095', '2017-01-10', 'ec'],
#  ['963', 'Hasta el Amanecer', 'Nicky Jam', '3066', '2017-01-10', 'ec'],
#  ['964',
#   'Si Me Dices Que Si (feat. Nicky Jam)',
#   'Cosculluela',
#   '3031',
#   '2017-01-10',
#   'ec'],
#  ['965', 'Una y otra vez', 'Manuel Medrano', '3007', '2017-01-10', 'ec'],
#  ['967', 'Bajo el agua', 'Manuel Medrano', '2924', '2017-01-10', 'ec'],
#  ['968', 'Ruleta Rusa', 'Kevin Roldan', '2924', '2017-01-10', 'ec'],
#  ['969',
#   'No Quiere Enamorarse (Remix) [feat. Daddy Yankee]',
#   'Ozuna',
#   '2923',
#   '2017-01-10',
#   'ec'],
#  ['970',
#   'Call On Me - Ryan Riback Extended Remix',
#   'Starley',
#   '2917',
#   '2017-01-10',
#   'ec'],
#  ['971', 'Ride', 'Twenty One Pilots', '2844', '2017-01-10', 'ec'],
#  ['972',
#   'Por Fin Te Encontré',
#   'Cali Y El Dandee',
#   '2829',
#   '2017-01-10',
#   'ec'],
#  ['973', 'Enamorándonos', 'Cabas', '2818', '2017-01-10', 'ec'],
#  ['974', 'Ya Me Enteré', 'Reik', '2799', '2017-01-10', 'ec'],
#  ['975', 'By Your Side', 'Jonas Blue', '2787', '2017-01-10', 'ec'],
#  ['976',
#   'Hymn For The Weekend - Seeb Remix',
#   'Coldplay',
#   '2783',
#   '2017-01-10',
#   'ec'],
#  ['977', 'Mercy', 'Shawn Mendes', '2753', '2017-01-10', 'ec'],
#  ['978',
#   'Light It Up (feat. Nyla & Fuse ODG) - Remix',
#   'Major Lazer',
#   '2716',
#   '2017-01-10',
#   'ec'],
#  ['979', 'Quisiera', 'CNCO', '2682', '2017-01-10', 'ec'],
#  ['980', 'El Chisme', 'Reykon', '2665', '2017-01-10', 'ec'],
#  ['981',
#   'Hasta Que Se Seque el Malecón - Remix',
#   'Jacob Forever',
#   '2662',
#   '2017-01-10',
#   'ec'],
#  ['982', 'Hear Me Now', 'Alok', '2638', '2017-01-10', 'ec'],
#  ['983', 'Love Yourself', 'Justin Bieber', '2606', '2017-01-10', 'ec'],
#  ['984', 'Shed a Light', 'Robin Schulz', '2573', '2017-01-10', 'ec'],
#  ['985', 'Dueles', 'Jesse & Joy', '2527', '2017-01-10', 'ec'],
#  ['986', 'Work', 'Rihanna', '2503', '2017-01-10', 'ec'],
#  ['987', 'Starving', 'Hailee Steinfeld', '2493', '2017-01-10', 'ec'],
#  ['988', 'Fake Love', 'Drake', '2474', '2017-01-10', 'ec'],
#  ['989', 'All We Know', 'The Chainsmokers', '2448', '2017-01-10', 'ec'],
#  ['990', 'Soy Peor', 'Bad Bunny', '2446', '2017-01-10', 'ec'],
#  ['991', 'Black Beatles', 'Rae Sremmurd', '2443', '2017-01-10', 'ec'],
#  ['992', 'Traicionera - Remix', 'Sebastian Yatra', '2439', '2017-01-10', 'ec'],
#  ['993', 'Que Raro', 'Feid', '2419', '2017-01-10', 'ec'],
#  ['994', 'Work from Home', 'Fifth Harmony', '2408', '2017-01-10', 'ec'],
#  ['995', 'Encantadora - Remix', 'Yandel', '2402', '2017-01-10', 'ec'],
#  ['996',
#   'Mi Tesoro (feat. Nicky Jam)',
#   'Zion & Lennox',
#   '2385',
#   '2017-01-10',
#   'ec'],
#  ['997', 'Alone', 'Alan Walker', '2384', '2017-01-10', 'ec'],
#  ['998',
#   'Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)',
#   'Arcangel',
#   '2363',
#   '2017-01-10',
#   'ec'],
#  ['999', 'Me Ama Me Odia', 'Ozuna', '2356', '2017-01-10', 'ec'],
#  ['1000', 'Reggaetón Lento (Bailemos)', 'CNCO', '18000', '2017-01-11', 'ec'],
#  ['1001', 'Chantaje', 'Shakira', '15980', '2017-01-11', 'ec'],
#  ['1002',
#   'Otra Vez (feat. J Balvin)',
#   'Zion & Lennox',
#   '13781',
#   '2017-01-11',
#   'ec'],
#  ['1003', 'Shape of You', 'Ed Sheeran', '13070', '2017-01-11', 'ec'],
#  ['1004', 'Safari', 'J Balvin', '12057', '2017-01-11', 'ec'],
#  ['1005', "Vente Pa' Ca", 'Ricky Martin', '11417', '2017-01-11', 'ec'],
#  ['1006', 'Let Me Love You', 'DJ Snake', '10429', '2017-01-11', 'ec'],
#  ['1007', 'Vacaciones', 'Wisin', '10132', '2017-01-11', 'ec'],
#  ['1008', 'Ay Mi Dios', 'IAmChino', '10097', '2017-01-11', 'ec'],
#  ['1009', 'Traicionera', 'Sebastian Yatra', '9105', '2017-01-11', 'ec'],
#  ['1010', 'Dile Que Tu Me Quieres', 'Ozuna', '8767', '2017-01-11', 'ec'],
#  ['1011', 'Closer', 'The Chainsmokers', '8506', '2017-01-11', 'ec'],
#  ['1012', "Don't Wanna Know", 'Maroon 5', '8162', '2017-01-11', 'ec'],
#  ['1013', 'Starboy', 'The Weeknd', '8130', '2017-01-11', 'ec'],
#  ['1014', 'Chillax', 'Farruko', '7942', '2017-01-11', 'ec'],
#  ['1015', '24K Magic', 'Bruno Mars', '7509', '2017-01-11', 'ec'],
#  ['1016', 'La Bicicleta', 'Carlos Vives', '7212', '2017-01-11', 'ec'],
#  ['1017', 'Andas En Mi Cabeza', 'Chino & Nacho', '7185', '2017-01-11', 'ec'],
#  ['1018', 'Cuatro Babys', 'Maluma', '7051', '2017-01-11', 'ec'],
#  ['1019',
#   'Me Llamas (feat. Maluma) - Remix',
#   'Piso 21',
#   '7047',
#   '2017-01-11',
#   'ec'],
#  ['1020', 'My Way', 'Calvin Harris', '7001', '2017-01-11', 'ec'],
#  ['1021', 'One Dance', 'Drake', '6960', '2017-01-11', 'ec'],
#  ['1022',
#   'Rockabye (feat. Sean Paul & Anne-Marie)',
#   'Clean Bandit',
#   '6831',
#   '2017-01-11',
#   'ec'],
#  ['1023', 'I Feel It Coming', 'The Weeknd', '6532', '2017-01-11', 'ec'],
#  ['1024', 'Shaky Shaky', 'Daddy Yankee', '6385', '2017-01-11', 'ec'],
#  ...]

# %%
music.head()
# Out:
# [['', 'Track Name', 'Artist', 'Streams', 'Date', 'Region'],
#  ['0', 'Reggaetón Lento (Bailemos)', 'CNCO', '19272', '2017-01-01', 'ec'],
#  ['1', 'Chantaje', 'Shakira', '19270', '2017-01-01', 'ec'],
#  ['2',
#   'Otra Vez (feat. J Balvin)',
#   'Zion & Lennox',
#   '15761',
#   '2017-01-01',
#   'ec'],
#  ['3', "Vente Pa' Ca", 'Ricky Martin', '14954', '2017-01-01', 'ec']]

# %%
music.data[-1]
# Out:
# ['37099', 'Alguien Robo', 'Sebastian Yatra', '2950', '2018-01-09', 'ec']

# %%
music.info()
# Out:
# [str, str, str, str, str, str]

# %%
music.shape()
# Out:
# (36121, 6)

# %%
music.new_column("test_column")

# %%
music.head()
# Out:
# [['', 'Track Name', 'Artist', 'Streams', 'Date', 'Region', 'test_column'],
#  ['0',
#   'Reggaetón Lento (Bailemos)',
#   'CNCO',
#   '19272',
#   '2017-01-01',
#   'ec',
#   'N/A'],
#  ['1', 'Chantaje', 'Shakira', '19270', '2017-01-01', 'ec', 'N/A'],
#  ['2',
#   'Otra Vez (feat. J Balvin)',
#   'Zion & Lennox',
#   '15761',
#   '2017-01-01',
#   'ec',
#   'N/A'],
#  ['3', "Vente Pa' Ca", 'Ricky Martin', '14954', '2017-01-01', 'ec', 'N/A']]

# %%
music.shape()
# Out:
# (36121, 7)

# %%
from random import random

(nrow,ncol) = music.shape()
new_vals = []
for i in range(nrow+1):
    if i==0:
        new_vals.append("new_vals")
    else:
        new_vals.append(str(random()))

print(len(new_vals))        
new_vals[0:5]
# Out:
# 36122
# ['new_vals',
#  '0.526189235720525',
#  '0.16142277019008977',
#  '0.5859931394940241',
#  '0.5976895515830822']

# %%
music.apply(6,new_vals,False)
music.head()
# Out:
# [['', 'Track Name', 'Artist', 'Streams', 'Date', 'Region', 'new_vals'],
#  ['0',
#   'Reggaetón Lento (Bailemos)',
#   'CNCO',
#   '19272',
#   '2017-01-01',
#   'ec',
#   '0.526189235720525'],
#  ['1',
#   'Chantaje',
#   'Shakira',
#   '19270',
#   '2017-01-01',
#   'ec',
#   '0.16142277019008977'],
#  ['2',
#   'Otra Vez (feat. J Balvin)',
#   'Zion & Lennox',
#   '15761',
#   '2017-01-01',
#   'ec',
#   '0.5859931394940241'],
#  ['3',
#   "Vente Pa' Ca",
#   'Ricky Martin',
#   '14954',
#   '2017-01-01',
#   'ec',
#   '0.5976895515830822']]

# %%
music.data[-1]
# Out:
# ['37099',
#  'Alguien Robo',
#  'Sebastian Yatra',
#  '2950',
#  '2018-01-09',
#  'ec',
#  '0.4140713543305111']

# %%
def apply(data,index,values,row):
    if row==True:
        data[index]=values
    else:
        i=0
        for row in data:
            row[index] = values[i]
            i += 1
    return data

# %%
test = [["1","2","3"],["4","5","6"]]
test2 = apply(test,1,["10","20"],True)
print(test2)
# Out:
# [['1', '2', '3'], ['10', '20']]

# %%
music.subset(2,"Shakira")

# %%
music.head()
# Out:
# [['1',
#   'Chantaje',
#   'Shakira',
#   '19270',
#   '2017-01-01',
#   'ec',
#   '0.16142277019008977'],
#  ['101',
#   'Chantaje',
#   'Shakira',
#   '15594',
#   '2017-01-02',
#   'ec',
#   '0.15584184581085303'],
#  ['201',
#   'Chantaje',
#   'Shakira',
#   '16614',
#   '2017-01-03',
#   'ec',
#   '0.4399478643341229'],
#  ['301',
#   'Chantaje',
#   'Shakira',
#   '16582',
#   '2017-01-04',
#   'ec',
#   '0.16425612560089675'],
#  ['401',
#   'Chantaje',
#   'Shakira',
#   '16254',
#   '2017-01-05',
#   'ec',
#   '0.6053222968888792']]

# %%
music.change_type(6,lambda x: float(x))

# %%
music.head()
# Out:
# [['1',
#   'Chantaje',
#   'Shakira',
#   '19270',
#   '2017-01-01',
#   'ec',
#   0.16142277019008977],
#  ['101',
#   'Chantaje',
#   'Shakira',
#   '15594',
#   '2017-01-02',
#   'ec',
#   0.15584184581085303],
#  ['201',
#   'Chantaje',
#   'Shakira',
#   '16614',
#   '2017-01-03',
#   'ec',
#   0.4399478643341229],
#  ['301',
#   'Chantaje',
#   'Shakira',
#   '16582',
#   '2017-01-04',
#   'ec',
#   0.16425612560089675],
#  ['401',
#   'Chantaje',
#   'Shakira',
#   '16254',
#   '2017-01-05',
#   'ec',
#   0.6053222968888792]]

# %%
music.summary_stats(6)
# Out:
# The mean is 0.5083549934064555.
# The median is 0.5163719177497641.
# The mode is undefined, likely all values different.
# The stdev is 0.2864735362460558.

# %%
music.maximum(6)
# Out:
# 0.9969422654876078

# %%
music.minimum(6)
# Out:
# 0.0027587279323803005

# %% [markdown]
# ### Use BabyPandas to answer the following question:
# - Which song was the top song of 2017?

# %%
# read in the data
music = BabyPandas("music_data.csv")
music.read_data()
music.head()
# Out:
# [['', 'Track Name', 'Artist', 'Streams', 'Date', 'Region'],
#  ['0', 'Reggaetón Lento (Bailemos)', 'CNCO', '19272', '2017-01-01', 'ec'],
#  ['1', 'Chantaje', 'Shakira', '19270', '2017-01-01', 'ec'],
#  ['2',
#   'Otra Vez (feat. J Balvin)',
#   'Zion & Lennox',
#   '15761',
#   '2017-01-01',
#   'ec'],
#  ['3', "Vente Pa' Ca", 'Ricky Martin', '14954', '2017-01-01', 'ec']]

# %%
# add a year column and subset to songs in 2017
from datetime import datetime
music.new_column("year")
music.change_type(4,lambda x: datetime.strptime(x,"%Y-%m-%d"))
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-30-dc317302a8ff> in <module>()
#       2 from datetime import datetime
#       3 music.new_column("year")
# ----> 4 music.change_type(4,lambda x: datetime.strptime(x,"%Y-%d-%m"))
#
# <ipython-input-1-821eb78a79e7> in change_type(self, index, new_type)
#      63     def change_type(self,index,new_type):
#      64         for row in self.data:
# ---> 65             row[index] = new_type(row[index])
#      66
#      67     def summary_stats(self,col_index):
#
# <ipython-input-30-dc317302a8ff> in <lambda>(x)
#       2 from datetime import datetime
#       3 music.new_column("year")
# ----> 4 music.change_type(4,lambda x: datetime.strptime(x,"%Y-%d-%m"))
#
# /usr/lib/python3.4/_strptime.py in _strptime_datetime(cls, data_string, format)
#     498     """Return a class cls instance based on the input string and the
#     499     format string."""
# --> 500     tt, fraction = _strptime(data_string, format)
#     501     tzname, gmtoff = tt[-2:]
#     502     args = tt[:6] + (fraction,)
#
# /usr/lib/python3.4/_strptime.py in _strptime(data_string, format)
#     335     if not found:
#     336         raise ValueError("time data %r does not match format %r" %
# --> 337                          (data_string, format))
#     338     if len(data_string) != found.end():
#     339         raise ValueError("unconverted data remains: %s" %
#
# ValueError: time data 'Date' does not match format '%Y-%d-%m'

# %%
# create a dictionary with track name and
# stream counts for 2017

# %%
datetime.strptime('2017-01-01',"%Y-%m-%d")
# Out:
# datetime.datetime(2017, 1, 1, 0, 0)

# %%
years=music.subset(4,rowval)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-31-92da21626910> in <module>()
# ----> 1 years=music[4]
#
# TypeError: 'BabyPandas' object does not support indexing

# %%
file = open("music_data.csv","r")
filestring = file.read()
stringlist = filestring.split("\n")
data = []
for row in stringlist:
    data.append(row.split(","))
data=data[:-1]

# %%
dates=[]
for row in data[1:]:
    dates.append(row[4])
dates
# Out:
# ['2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  'Farruko',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2218',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  ' Zion & Lennox]"',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-01',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  'Farruko',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2497',
#  '2017-01-02',
#  '2017-01-02',
#  ' Zion & Lennox]"',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-02',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  'Farruko',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  ' Zion & Lennox]"',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2574',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-03',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  'Farruko',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  ' Zion & Lennox]"',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2497',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-04',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  'Farruko',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  ' Zion & Lennox]"',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2650',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-05',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  'Farruko',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  ' Zion & Lennox]"',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2690',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-06',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  'Farruko',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  ' Zion & Lennox]"',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-07',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  'Farruko',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  ' Zion & Lennox]"',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-08',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  'Farruko',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  ' Zion & Lennox]"',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-09',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  'Farruko',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  ' Zion & Lennox]"',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  '2017-01-10',
#  ...]

# %%
lengths = []
for date in dates:
    lengths.append(len(date))
lengths
# Out:
# [10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  7,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  4,
#  10,
#  10,
#  10,
#  10,
#  10,
#  16,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  7,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  4,
#  10,
#  10,
#  16,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  7,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  16,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  4,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  7,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  16,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  4,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  7,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  16,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  4,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  7,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  16,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  4,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  7,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  16,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  7,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  16,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  7,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  16,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  7,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  16,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  ...]

# %%
max(lengths)
# Out:
# 23

# %%
min(lengths)
# Out:
# 4

# %%
weird_dates=[]
for date in dates:
    if len(date) != 10:
        weird_dates.append(date)
weird_dates
# Out:
# ['Farruko',
#  '2218',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '2497',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  '2574',
#  'Farruko',
#  ' Zion & Lennox]"',
#  '2497',
#  'Farruko',
#  ' Zion & Lennox]"',
#  '2650',
#  'Farruko',
#  ' Zion & Lennox]"',
#  '2690',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  ' Messiah & Baby Rasta]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Messiah & Baby Rasta]"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3721',
#  ' Zion & Lennox]"',
#  '4045',
#  'Farruko',
#  ' Zion & Lennox]"',
#  '4347',
#  'Farruko',
#  ' Zion & Lennox]"',
#  '4371',
#  'Farruko',
#  ' Zion & Lennox]"',
#  '4097',
#  'Farruko',
#  ' Zion & Lennox]"',
#  '4729',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '4768',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '4090',
#  ' Zion & Lennox]"',
#  '4068',
#  'Farruko',
#  ' Zion & Lennox]"',
#  '4141',
#  'Farruko',
#  ' Zion & Lennox]"',
#  '4129',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3948',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3949',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '4288',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3674',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3716',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3540',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3807',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3837',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3986',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '4138',
#  ' Cosculluela)"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3807',
#  ' Cosculluela)"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3569',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3731',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3705',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3702',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3968',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '4191',
#  ' Cosculluela)"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3589',
#  ' Cosculluela)"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3321',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3277',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3222',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3369',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3755',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3746',
#  ' Cosculluela)"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3178',
#  ' Cosculluela)"',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3085',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3067',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3224',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3358',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3649',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3816',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3369',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3127',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3350',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3491',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3246',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3729',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3538',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3221',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3149',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3311',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3394',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3399',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3691',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3570',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3277',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '2928',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3172',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3330',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3494',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3559',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3762',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3096',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3159',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3144',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3254',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3316',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3438',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3650',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3286',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3018',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3062',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3235',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3527',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3544',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3930',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3489',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3337',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3328',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3236',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3553',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3682',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3999',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3557',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3486',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3649',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3401',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3397',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3630',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3526',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3349',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3032',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3164',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3146',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3279',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3567',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3549',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3239',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '2969',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3007',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3134',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3211',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3251',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3646',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3276',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3213',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '2830',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '2708',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '2953',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3305',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3329',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3047',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '2766',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '2831',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '2911',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3025',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3267',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3550',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '2949',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '2708',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3005',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3025',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '2967',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3141',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3267',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '2891',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3272',
#  ' Zion & Lennox]"',
#  '3922',
#  'Farruko',
#  '2900',
#  ' Zion & Lennox]"',
#  '3986',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '4042',
#  '3141',
#  ' Zion & Lennox]"',
#  '3885',
#  'Farruko',
#  '3062',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3565',
#  '2861',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3500',
#  ' Zion & Lennox]"',
#  '3640',
#  'Farruko',
#  ' Zion & Lennox]"',
#  '3872',
#  'Farruko',
#  ' Zion & Lennox]"',
#  '3922',
#  'Farruko',
#  ' Zion & Lennox]"',
#  '3751',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3951',
#  'Jennifer Lopez',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '4046',
#  'Jennifer Lopez',
#  ' Zion & Lennox]"',
#  'Farruko',
#  '3560',
#  'Jennifer Lopez',
#  ' Zion & Lennox]"',
#  'Farruko',
#  'Jennifer Lopez',
#  '3245',
#  ' Zion & Lennox]"',
#  'Farruko',
#  'Jennifer Lopez',
#  '3200',
#  ' Zion & Lennox]"',
#  'Farruko',
#  'Jennifer Lopez',
#  '3324',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  '3129',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  '3770',
#  ' Zion & Lennox]"',
#  'Farruko',
#  'Jennifer Lopez',
#  '3623',
#  '3011',
#  ' Zion & Lennox]"',
#  'Farruko',
#  'Jennifer Lopez',
#  '2873',
#  '2803',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  'Jennifer Lopez',
#  '2902',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  '3081',
#  ' Zion & Lennox]"',
#  'Farruko',
#  'Jennifer Lopez',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  'Jennifer Lopez',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  'Jennifer Lopez',
#  ' Zion & Lennox]"',
#  'Farruko',
#  'Jennifer Lopez',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  'Jennifer Lopez',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  '3461',
#  'Farruko',
#  '6322',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  'Farruko',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez',
#  '2971',
#  ' Zion & Lennox]"',
#  'Jennifer Lopez']

# %%
len(weird_dates[1])
# Out:
# 10
